# %%
import sqlite3
import json

# %%
all = set()
with open('../data/test_entity_data.json', 'r') as f:
    t = json.loads(f.read())
    print(len(t))
    for item in t:
        id = item[0]
        name = item[1][0]
        instance = item[1][1]
        ar = item[2].get('ar', '')
        de = item[2].get('de', '')
        es = item[2].get('es', '')
        fr = item[2].get('fr', '')
        it = item[2].get('it', '')
        ja = item[2].get('ja', '')

        tup = (id,name,instance, ar, de, es, fr, it, ja)
        all.add(tup)
# Out:
# 6641
# {('Q369547',
#   'Sázava Monastery',
#   'monastery',
#   '',
#   'Kloster Sázava',
#   'Monasterio de Sázava',
#   'monastère de Sázava',
#   'Monastero di Sázava',
#   ''),
#  ('Q779815',
#   'animation director',
#   'filmmaking occupation',
#   'مخرج رسوم متحركة',
#   'Regisseur für Animation',
#   'director de animación',
#   'chef-animateur',
#   "direttore dell'animazione",
#   '作画監督'),
#  ('Q863438',
#   'The Valley of Fear',
#   'literary work',
#   'وادي الخوف',
#   'Das Tal der Angst',
#   'El valle del terror',
#   'La Vallée de la peur',
#   'La valle della paura',
#   '恐怖の谷'),
#  ('Q853935',
#   'Kocatepe Mosque',
#   'mosque',
#   'جامع خوجه تبه',
#   'Kocatepe-Moschee',
#   'Mezquita Kocatepe',
#   'mosquée Kocatepe',
#   '',
#   'コジャテペ・モスク'),
#  ('Q506505',
#   'The Comedy of Errors',
#   'dramatic work',
#   'كوميديا الأخطاء',
#   'Die Komödie der Irrungen',
#   'La comedia de las equivocaciones',
#   'La Comédie des erreurs',
#   'La commedia degli errori',
#   '間違いの喜劇'),
#  ('Q13923',
#   'The Grim Adventures of Billy & Mandy',
#   'animated television series',
#   'مغامرات بيلي وماندي',
#   'Die gruseligen Abenteuer von Billy und Mandy',
#   'The Grim Adventures of Billy & Mandy',
#   "Billy et Mandy, aventuriers de l'au-delà",
#   'Le tenebrose avventure di Billy e Mandy',
#   'ビリー&マンディ'),
#  ('Q974775',
#   'Olympiodorus the Younger',
#   'human',
#   'أولمبردس الصغير',
#   'Olympiodoros der Jüngere',
#   'Olimpiodoro el Joven',
#   'Olympiodore le Jeune',
#   'Olimpiodoro il Giovane',
#   'オリンピオドロス'),
#  ('Q80692',
#   'Richeza of Poland, Queen of Castile',
#   'human',
#   'ريكولدا من بولندا',
#   'Richeza von Everstein',
#   'Riquilda de Polonia',
#   'Richezza de Pologne',
#   'Richenza di Polonia',
#   'リクサ・シロンスカ'),
#  ('Q1352126',
#   'Melitius of Lycopolis',
#   'human',
#   '',
#   'Meletios von Lykopolis',
#   'Melicio de Licòpolis',
#   'Mélitios de Lycopolis',
#   'Melezio di Licopoli',
#   'リコポリスのメレティオス'),
#  ('Q12204253',
#   'Al-Sayeda Nafeesah Mosque',
#   'mosque',
#   'جامع السيدة نفيسة',
#   'Saiyida-Nafisa-Moschee',
#   'Al-Sayyida Nafisa',
#   'Al-Sayyida Nafisa',
#   '',
#   ''),
#  ('Q28102177',
#   'My Knight and Me',
#   'television series',
#   '',
#   'Ritter Hoch 3',
#   'Mi Caballero y Yo',
#   'Mon chevalier et moi',
#   "L'apprendista cavaliere",
#   '私の騎士と私'),
#  ('Q51403',
#   'Man in Black',
#   'fictional human',
#   '',
#   'Mann in Schwarz',
#   'Hombre de Negro',
#   "L'homme en noir",
#   'Uomo in nero',
#   '黒服の男'),
#  ('Q271815',
#   'Eleanor, Countess of Vermandois',
#   'human',
#   '',
#   'Eleonore von Vermandois',
#   'Eleonor de Vermandois',
#   'Éléonore de Vermandois',
#   'Eleonora di Vermandois',
#   'エレオノール (ヴェルマンドワ女伯)'),
#  ('Q93535',
#   'Marie Christine, Princess Michael of Kent',
#   'human',
#   'مايكل أميرة كينت',
#   'Marie Christine von Reibnitz',
#   'María Cristina de Reibnitz',
#   'Marie-Christine von Reibnitz',
#   'Marie Christine von Reibnitz',
#   'マリー＝クリスティーヌ'),
#  ('Q2570624',
#   'Radisson Royal Hotel',
#   'hotel',
#   'فندق أوكرانيا',
#   '',
#   'Hotel Ucrania',
#   'hôtel Ukraine',
#   'Hotel Ucraina',
#   'ホテル・ウクライナ'),
#  ('Q6661985',
#   'data processing',
#   'information processing',
#   'معالجة البيانات',
#   'Datenverarbeitung',
#   'procesamiento de datos',
#   'traitement de données',
#   'elaborazione dati',
#   'データ処理'),
#  ('Q3203583',
#   'Man a Machine',
#   'literary work',
#   '',
#   '',
#   'El hombre máquina',
#   "L'Homme Machine",
#   "L'Homme Machine",
#   '人間機械論'),
#  ('Q14906755',
#   'Cloak of Invisibility',
#   'magical object in Harry Potter',
#   '',
#   'Tarnumhang',
#   'Capa de Invisibilidad',
#   "Cape d'invisibilité",
#   "Mantello dell'invisibilità",
#   ''),
#  ('Q844473',
#   'Dark Eyes',
#   'musical work/composition',
#   'العيون السوداء',
#   'Schwarze Augen',
#   'Ojos Negros',
#   'Les Yeux noirs',
#   'Occhi neri',
#   '黒い瞳'),
#  ('Q1198412',
#   'Too Late for Tears',
#   'film',
#   '',
#   'Der blonde Tiger',
#   'Demasiado tarde para lágrimas',
#   'La Tigresse',
#   'È tardi per piangere',
#   'トゥー・レイト・フォー・ティアーズ'),
#  ('Q1076874',
#   'fried rice',
#   'dish',
#   'الأرز المقلي',
#   'gebratener Reis',
#   'arroz frito',
#   'riz frit',
#   'riso fritto',
#   'チャーハン'),
#  ('Q175565',
#   'String Quartet No. 13',
#   'musical work/composition',
#   '',
#   '13. Streichquartett',
#   'Cuarteto de cuerda n.º 13 Op. 130',
#   'Quatuor à cordes nº 13 de Beethoven',
#   'Quartetto n. 13',
#   '弦楽四重奏曲第13番 (ベートーヴェン)'),
#  ('Q1437026',
#   'Two Half Times in Hell',
#   'film',
#   '',
#   'Zwei Halbzeiten in der Hölle',
#   'Match en el infierno',
#   'Deux Mi-temps en enfer',
#   "Due tempi all'inferno",
#   '地獄のハーフタイム'),
#  ('Q628443',
#   'The Steam House',
#   'literary work',
#   'بيت البخار',
#   'Das Dampfhaus',
#   'La casa de vapor',
#   'La Maison à vapeur',
#   'La casa a vapore',
#   '蒸気の家'),
#  ('Q1016744',
#   'Bornay Mosque',
#   'mosque',
#   'مسجد بورناي',
#   'Burnajewskaja-Moschee',
#   '',
#   '',
#   '',
#   ''),
#  ('Q941517',
#   'Imagination Movers',
#   'television series',
#   'محركو الخيال',
#   'Die Ideen-Meister',
#   'Los Imaginadores',
#   '',
#   '',
#   'あそぼう!イマジネーションムーバーズ'),
#  ('Q107351551',
#   'Sāmī ʻĀmirī',
#   'human',
#   'سامي عامري',
#   'Sami Ameri',
#   '',
#   'Sami Ameri',
#   '',
#   ''),
#  ('Q47464862',
#   'The Heroic Quest of the Valiant Prince Ivandoe',
#   'animated television series',
#   'السعي البطولي للأمير الشجاع آيفاندو',
#   'Die heldenhafte Reise des tapferen Prinz Ivandoe',
#   'El valiente príncipe Ivandoe',
#   'La Quête héroïque du valeureux Prince Ivandoe',
#   'Il principe Ivandoe',
#   ''),
#  ('Q930887',
#   'Vegas Vacation',
#   'film',
#   'عطلة فيغاس',
#   'Die schrillen Vier in Las Vegas',
#   'Vacaciones en Las Vegas',
#   'Bonjour les vacances : Viva Las Vegas',
#   'Las Vegas - Una vacanza al casinò',
#   'ベガス・バケーション'),
#  ('Q2344561',
#   'Putra Mosque',
#   'mosque',
#   'مسجد بوترا',
#   'Putra-Moschee',
#   'Mezquita Putra',
#   'mosquée Putra',
#   '',
#   'プトラ・モスク'),
#  ('Q498384',
#   'Back from Eternity',
#   'film',
#   '',
#   'Zurück aus der Ewigkeit',
#   'Regreso de la eternidad',
#   'Les Échappés du néant',
#   "Ritorno dall'eternità",
#   '地獄の罠'),
#  ('Q738056',
#   'The Iron Mask',
#   'film',
#   'القناع الحديدي',
#   'Die eiserne Maske',
#   'La máscara de hierro',
#   'Le Masque de fer',
#   'La maschera di ferro',
#   '鉄仮面'),
#  ('Q5694782',
#   'Heaven and Hell',
#   'literary work',
#   '',
#   'Himmel und Hölle',
#   'De caelo et ejus mirabilibus et de inferno, ex auditis et visis',
#   '',
#   'Cielo e inferno',
#   ''),
#  ('Q4645817',
#   '92 in the Shade',
#   'film',
#   '',
#   '33 Grad im Schatten',
#   'Venganza anunciada',
#   "Trente-sept degrés à l'ombre",
#   "Novantadue gradi all'ombra",
#   ''),
#  ('Q5917807',
#   'How I Live Now',
#   'literary work',
#   '',
#   'So lebe ich jetzt',
#   '',
#   "Maintenant, c'est ma vie",
#   '',
#   ''),
#  ('Q1233716',
#   'Big Deal on Madonna Street',
#   'film',
#   '',
#   'Diebe haben’s schwer',
#   'Los desconocidos de siempre',
#   'Le Pigeon',
#   'I soliti ignoti',
#   'いつもの見知らぬ男たち'),
#  ('Q2562710',
#   'Waves of the Danube',
#   'musical work/composition',
#   '',
#   'Donauwellen',
#   'Olas del Danubio',
#   'Les Flots du Danube',
#   'Le onde del Danubio',
#   'ドナウ川のさざなみ'),
#  ('Q500538',
#   'High School Girls',
#   'manga series',
#   'هاي سكول غيرلز',
#   'Joshi Kōsei',
#   'Joshikōsei',
#   '',
#   '',
#   '女子高生'),
#  ('Q81329957',
#   'My Roomie Is a Dino',
#   'manga',
#   '',
#   '',
#   'Gal to Kyōryū',
#   '',
#   '',
#   'ギャルと恐竜'),
#  ('Q16165135',
#   'Pig Goat Banana Cricket',
#   'television series',
#   'بيغ غوت بانانا كريكيت',
#   'Schwein Ziege Banane Grille',
#   'Cerdo Cabra Banana Grillo',
#   'Cochon Chèvre Banane Criquet',
#   'Maiale Capra Banana Grillo',
#   ''),
#  ('Q7741197',
#   'The Hydrogen Sonata',
#   'literary work',
#   '',
#   'Die Wasserstoffsonate',
#   'La sonata del hidrógeno',
#   'La Sonate Hydrogène',
#   '',
#   '水素ソナタ'),
#  ('Q1751487',
#   'Platov South-Russian State Polytechnic University',
#   'university',
#   'جامعة جنوب روسيا التقنية',
#   'Südrussische Staatliche Technische Universität',
#   'Universidad Técnica Estatal del Sur de Rusia',
#   "université technique d'État de Novotcherkassk",
#   '',
#   ''),
#  ('Q334051',
#   'Abbey of Monte Cassino',
#   'benedictine abbey',
#   '',
#   'Abtei Montecassino',
#   'abadía de Montecasino',
#   'abbaye du Mont-Cassin',
#   'abbazia di Montecassino',
#   'モンテ・カッシーノ修道院'),
#  ('Q131097',
#   'Epistle of James',
#   'religious text',
#   'رسالة يعقوب',
#   'Jakobus',
#   'Epístola de Santiago',
#   'Épître de Jacques',
#   'Lettera di Giacomo',
#   'ヤコブの手紙'),
#  ('Q7467',
#   'Priory Palace',
#   'palace',
#   '',
#   'Prioren Palast',
#   'Palacio del Priorato',
#   'palais du Prieuré',
#   'Palazzo del Priorato',
#   ''),
#  ('Q3213985',
#   'The Truth About the Harry Quebert Affair',
#   'literary work',
#   '',
#   'Die Wahrheit über den Fall Harry Quebert',
#   'La verdad sobre el caso Harry Quebert',
#   "La Vérité sur l'affaire Harry Quebert",
#   'La verità sul caso Harry Quebert',
#   ''),
#  ('Q4965928',
#   'Brick Lane Mosque',
#   'mosque',
#   'مسجد بريك لين',
#   'Brick-Lane-Moschee',
#   '',
#   '',
#   '',
#   ''),
#  ('Q1321004',
#   'You Will Meet a Tall Dark Stranger',
#   'film',
#   '',
#   'Ich sehe den Mann deiner Träume',
#   'Conocerás al hombre de tus sueños',
#   'Vous allez rencontrer un bel et sombre inconnu',
#   "Incontrerai l'uomo dei tuoi sogni",
#   '恋のロンドン狂騒曲'),
#  ('Q1699208',
#   'Ras Cory',
#   'musical group',
#   '',
#   'Midnite',
#   'Midnite',
#   'Midnite',
#   'Midnite',
#   'ミッドナイト'),
#  ('Q2378785',
#   'Beatrice of Bohemia',
#   'human',
#   '',
#   'Beatrice von Böhmen',
#   'Beatriz de Bohemia',
#   'Béatrice de Bohême',
#   '',
#   'ベアトリクス・フォン・ベーメン'),
#  ('Q242287',
#   'Joan of England',
#   'human',
#   '',
#   'Johanna von England',
#   'Juana de Inglaterra, reina de Escocia',
#   "Jeanne d'Angleterre",
#   'Giovanna Plantageneto',
#   'ジョーン・オブ・イングランド'),
#  ('Q2115452',
#   'Prelude in C-sharp minor',
#   'musical work/composition',
#   '',
#   'Prélude cis-Moll',
#   'Preludio en do sostenido menor (Rajmáninov)',
#   '',
#   'Preludio in Do diesis minore',
#   '前奏曲嬰ハ短調 (ラフマニノフ)'),
#  ('Q2388422',
#   'Kudrinskaya Square Building',
#   'revenue house',
#   '',
#   '',
#   'Edificio de la plaza Kudrinskaya',
#   "immeuble d'habitation de la place Koudrine",
#   'Edificio residenziale in piazza Kudrinskaja',
#   ''),
#  ('Q11872',
#   'The Steadfast Tin Soldier',
#   'literary work',
#   '',
#   'Der standhafte Zinnsoldat',
#   'El soldadito de plomo',
#   'Le Stoïque Soldat de plomb',
#   'Il soldatino di stagno',
#   'しっかり者のスズの兵隊'),
#  ('Q1617364',
#   "Dr. Terror's House of Horrors",
#   'film',
#   '',
#   'Die Todeskarten des Dr. Schreck',
#   'Doctor Terror',
#   'Le Train des épouvantes',
#   'Le cinque chiavi del terrore',
#   'テラー博士の恐怖'),
#  ('Q12170857',
#   'Klim Churyumov',
#   'human',
#   'كليم تشوريوموف',
#   'Klym Tschurjumow',
#   'Klim Churyumov',
#   'Klym Tchourioumov',
#   'Klym Čurjumov',
#   'クリム・チュリュモフ'),
#  ('Q707502',
#   'The Rape of Nanking',
#   'written work',
#   'اغتصاب نانكينغ (كتاب)',
#   '',
#   '',
#   'Le viol de Nankin',
#   'Lo stupro di Nanchino',
#   'ザ・レイプ・オブ・南京'),
#  ('Q2024169',
#   'Princess Désirée, Baroness Silfverschiöld',
#   'human',
#   '',
#   'Désirée Silfverschiöld',
#   'Désirée Bernadotte',
#   'Désirée de Suède',
#   'Desirée di Svezia',
#   ''),
#  ('Q2638238',
#   'Vyborg railway station',
#   'railway station',
#   '',
#   'Wyborg',
#   '',
#   'Vyborg',
#   '',
#   ''),
#  ('Q1093846',
#   'La Seine no Hoshi',
#   'anime television series',
#   '',
#   'Nadine – Stern der Seine',
#   '',
#   'La Tulipe noire',
#   'Il Tulipano Nero',
#   'ラ・セーヌの星'),
#  ('Q804208',
#   'Bajrakli Mosque',
#   'mosque',
#   'مسجد بجراكلي (بلغراد)',
#   'Bajrakli-Moschee (Belgrad)',
#   'Mezquita Bajrakli',
#   'mosquée Bajrakli de Belgrade',
#   '',
#   'バイラクリ・モスク'),
#  ('Q1306291',
#   'A Memory of Solferino',
#   'literary work',
#   '',
#   'Eine Erinnerung an Solferino',
#   'Un recuerdo de Solferino',
#   'Un souvenir de Solférino',
#   'Un Souvenir de Solférino',
#   'ソルフェリーノの思い出'),
#  ('Q2594210',
#   'Seal of Solomon',
#   'seal',
#   'خاتم سليمان',
#   '',
#   'Sello de Salomón (leyenda)',
#   'Sceau de Salomon',
#   '',
#   'ソロモンの指輪'),
#  ('Q17071479',
#   'Who Fears Death',
#   'literary work',
#   'من يخاف الموت',
#   '',
#   '',
#   'Qui a peur de la mort ?',
#   '',
#   ''),
#  ('Q7860088',
#   'Tyler Moon',
#   'fictional human',
#   '',
#   '',
#   'Tony Discipline',
#   '',
#   '',
#   ''),
#  ('Q728404',
#   'The Pelican Brief',
#   'film',
#   'قضية البجع',
#   'Die Akte',
#   'El informe Pelícano',
#   "L'Affaire Pélican",
#   'Il rapporto Pelican',
#   'ペリカン文書'),
#  ('Q4189105',
#   'Memorial to Defenders of the Soviet Arctic during the Great Patriotic War',
#   'monumental sculpture',
#   'نصب أليوشا التذكاري',
#   'Aljoscha-Monument',
#   '',
#   "monument aux défenseurs de l'Arctique soviétique pendant la Grande Guerre patriotique",
#   "Monumento ai difensori dell'Artico sovietico durante la grande guerra patriottica",
#   'ソビエト極北防衛隊慰霊碑'),
#  ('Q1637730',
#   'The Dark Tower III: The Waste Lands',
#   'literary work',
#   'برج الظلام 3: الأراضي اليباب (رواية)',
#   'Tot',
#   'Las tierras baldías',
#   'Terres perdues',
#   'Terre desolate',
#   ''),
#  ('Q1010828',
#   'Aremberg Castle',
#   'castle',
#   '',
#   'Burg Aremberg',
#   'castillo de Aremberg',
#   '',
#   '',
#   ''),
#  ('Q60063045',
#   'The Light in Your Eyes',
#   'television series',
#   'النور في عينيك',
#   'Radiant',
#   'Radiant (La luz en tus ojos)',
#   '',
#   'Nun-i busige',
#   '眩しくて'),
#  ('Q1002362',
#   'The Signal-Man',
#   'literary work',
#   'عامل الإشارة',
#   '',
#   'El guardavía',
#   '',
#   'Il segnalatore',
#   'The Signal-Man'),
#  ('Q1912490',
#   'Prince Max, Duke in Bavaria',
#   'human',
#   '',
#   'Prinz Max Emanuel, Herzog in Bayern',
#   'Max Emanuel de Baviera',
#   'Max Emmanuel von Wittelsbach',
#   'Max in Baviera',
#   'マックス・エマヌエル・イン・バイエルン'),
#  ('Q311441',
#   "Al-Rifa'i Mosque",
#   'mosque',
#   'مسجد الرفاعي',
#   "Ar-Rifa'i-Moschee",
#   "Mezquita de Al Rifa'i",
#   "mosquée Al-Rifa'i",
#   "moschea di al-Rifa'i",
#   'アッ＝リファーイー・モスク'),
#  ('Q3227112',
#   'The Promise',
#   'television series',
#   'الوعد',
#   'Gelobtes Land',
#   'La promesa',
#   'Le Serment',
#   '',
#   ''),
#  ('Q96377121',
#   'The Hunger Games: The Ballad of Songbirds and Snakes',
#   'prequel',
#   'مباريات الجوع: أغنية الطيور المغردة والثعابين',
#   'Die Tribute von Panem – The Ballad of Songbirds and Snakes',
#   'Los juegos del hambre: balada de pájaros cantores y serpientes',
#   "Hunger Games : La Ballade du serpent et de l'oiseau chanteur",
#   "Hunger Games - La ballata dell'usignolo e del serpente",
#   'ハンガー・ゲーム0'),
#  ('Q246546',
#   'Symphony No. 6',
#   'musical work/composition',
#   '',
#   '6. Sinfonie',
#   'Sinfonía n.º 6',
#   'Symphonie nº 6 de Sibelius',
#   'Sinfonia n. 6',
#   '交響曲第6番 (シベリウス)'),
#  ('Q963659',
#   'Dombey and Son',
#   'literary work',
#   'دومبي وابنه',
#   'Dombey und Sohn',
#   'Dombey e hijo',
#   'Dombey et Fils',
#   'Dombey e Figlio',
#   'ドンビー父子'),
#  ('Q727016',
#   'Boys Town',
#   'film',
#   'مدينة الصبيان',
#   'Teufelskerle',
#   'Forja de hombres',
#   'Des hommes sont nés',
#   'La città dei ragazzi',
#   '少年の町'),
#  ('Q2296177',
#   'Andrey of Gorodets',
#   'human',
#   '',
#   'Andrei Alexandrowitsch von Gorodez',
#   'Andréi III de Vladímir',
#   'André III de Vladimir',
#   'Andrea III di Vladimir',
#   'アンドレイ・アレクサンドロヴィチ'),
#  ('Q14601067',
#   'Gypsy sauce',
#   'condiment',
#   '',
#   'Zigeunersauce',
#   'Salsa zíngara',
#   '',
#   '',
#   ''),
#  ('Q76907',
#   'Henry IV, Count of Luxembourg',
#   'human',
#   'هنري الرابع، كونت لوكسمبورغ',
#   'Heinrich IV.',
#   'Enrique IV de Luxemburgo',
#   'Henri IV de Luxembourg',
#   'Enrico IV di Lussemburgo',
#   'ハインリヒ4世'),
#  ('Q5361036',
#   'SPEC〜Keishichyō Kōanbu Kōandaigoka Mishōjiken Tokubetsugakari Jikenbo〜',
#   'television program',
#   '',
#   '',
#   '',
#   'Keizoku 2: SPEC',
#   '',
#   'SPEC〜警視庁公安部公安第五課 未詳事件特別対策係事件簿〜'),
#  ('Q111490',
#   'Geoffrey Plantagenet, Count of Anjou',
#   'human',
#   'جيفري الخامس كونت أنجو',
#   'Gottfried V.',
#   'Godofredo V de Anjou',
#   "Geoffroy V d'Anjou",
#   "Goffredo V d'Angiò",
#   'ジョフロワ4世'),
#  ('Q20182063',
#   'Maggi seasoning',
#   'sauce',
#   '',
#   'Maggi-Würze',
#   '',
#   '',
#   '',
#   'マギーソース'),
#  ('Q60738660',
#   'The Boy Who Harnessed the Wind',
#   'film',
#   'الصبي الذي سخر الرياح',
#   'Der Junge, der den Wind einfing',
#   'El niño que domó el viento',
#   'Le Garçon qui dompta le vent',
#   'Il ragazzo che catturò il vento',
#   '風をつかまえた少年'),
#  ('Q1216187',
#   'Beauty and the Beast',
#   'television series',
#   'الجميلة والوحش',
#   'Die Schöne und das Biest',
#   'La bella y la bestia',
#   'La Belle et la Bête',
#   'La bella e la bestia',
#   '1987年の同名番組'),
#  ('Q3490213',
#   'Violin Sonata No. 3',
#   'musical work/composition',
#   '',
#   '',
#   'Sonata para violín n.° 3 (Brahms)',
#   'Sonate pour violon et piano n° 3',
#   'Sonata n.3 per violino e pianoforte',
#   'ヴァイオリンソナタ第3番 (ブラームス)'),
#  ('Q104580110',
#   'Ruin and Rising',
#   'literary work',
#   '',
#   'Lodernde Schwingen',
#   '',
#   "L'Oiseau de feu",
#   'Rovina e ascesa',
#   ''),
#  ('Q2280840',
#   'Ganbare Genki',
#   'anime television series',
#   'فارس الفتى الشجاع',
#   '',
#   '',
#   '',
#   'Forza Genki - Forza Sugar',
#   'がんばれ元気'),
#  ('Q2444377',
#   'Smolenskoye Orthodox Cemetery',
#   'cemetery',
#   '',
#   'Smolensker Friedhof',
#   'Cementerio Ortodoxo de Smolensk',
#   'cimetière orthodoxe de Smolensk',
#   '',
#   'スモレンスキー墓地'),
#  ('Q1291779',
#   'Al-Zaytuna Mosque',
#   'mosque',
#   'جامع الزيتونة',
#   'Ez-Zitouna-Moschee',
#   'Mezquita Zitouna',
#   'mosquée Zitouna',
#   'moschea al-Zaytuna',
#   'ザイトゥーナモスク'),
#  ('Q1299410',
#   'Investigation of a Citizen Above Suspicion',
#   'film',
#   'تحقيق مع مواطن فوق مستوى الشبهات',
#   'Ermittlungen gegen einen über jeden Verdacht erhabenen Bürger',
#   'Investigación sobre un ciudadano libre de toda sospecha',
#   'Enquête sur un citoyen au-dessus de tout soupçon',
#   'Indagine su un cittadino al di sopra di ogni sospetto',
#   '殺人捜査'),
#  ('Q2270201',
#   'Floris and Blancheflour',
#   'literary work',
#   '',
#   'Floire et Blancheflor',
#   'Flores y Blancaflor',
#   'Floire et Blancheflor',
#   '',
#   ''),
#  ('Q1570778',
#   'Little Princess',
#   'television series',
#   '',
#   'Kleine Prinzessin',
#   'Princesita',
#   'Petite Princesse',
#   '',
#   'リトルプリンセス'),
#  ('Q823691',
#   'The Country of the Blind',
#   'literary work',
#   'بلد العميان',
#   'Das Land der Blinden',
#   'El país de los ciegos',
#   'Le Pays des aveugles',
#   'Il paese dei ciechi',
#   ''),
#  ('Q2492950',
#   'Nine Princes in Amber',
#   'literary work',
#   '',
#   'Corwin von Amber',
#   'Los nueve príncipes de Ámbar',
#   "Les Neuf Princes d'Ambre",
#   'Nove principi in Ambra',
#   ''),
#  ('Q25396205',
#   'Derbent Synagogue',
#   'synagogue',
#   '',
#   'Kele-Numas',
#   'Sinagoga de Derbent',
#   '',
#   '',
#   ''),
#  ('Q3834368',
#   'bounty hunter',
#   'fictional profession',
#   '',
#   'Kopfgeldjäger',
#   'Cazarrecompensas (Star Wars)',
#   '',
#   'Lista di cacciatori di taglie minori (Guerre stellari)',
#   ''),
#  ('Q2071759',
#   'Cool Air',
#   'literary work',
#   'الهواء البارد',
#   '',
#   'Aire frío',
#   'Air froid',
#   'Aria fredda',
#   '冷気'),
#  ('Q2478988',
#   'Mole Man',
#   'comics character',
#   '',
#   '',
#   'Hombre Topo',
#   "L'Homme-taupe",
#   'Uomo Talpa',
#   'モールマン'),
#  ('Q645157',
#   'Poblet Monastery',
#   'church building',
#   '',
#   'Monestir de Santa Maria de Poblet',
#   'Monasterio de Poblet',
#   'monastère de Poblet',
#   'Monastero di Santa Maria di Poblet',
#   'ポブレー修道院'),
#  ('Q377882',
#   'Royaumont Abbey',
#   'abbey',
#   '',
#   'Kloster Royaumont',
#   '',
#   'abbaye de Royaumont',
#   'Abbazia di Royaumont',
#   'ロワイヨモン修道院'),
#  ('Q352940',
#   'Louis of Evreux',
#   'human',
#   'لويس، كونت إفرو',
#   'Ludwig',
#   'Luis de Évreux',
#   "Louis d'Évreux",
#   "Luigi d'Évreux",
#   'ルイ・デヴルー'),
#  ('Q43228',
#   'Goodbye, Mr. Chips',
#   'film',
#   'الوداع يا سيد تشيبس',
#   'Auf Wiedersehen, Mr. Chips',
#   'Adiós, Mr. Chips',
#   'Au revoir Mr. Chips',
#   'Addio, Mr. Chips!',
#   'チップス先生さようなら'),
#  ('Q426433',
#   'Not as a Stranger',
#   'film',
#   '',
#   '… und nicht als ein Fremder',
#   'No serás un extraño',
#   'Pour que vivent les hommes',
#   'Nessuno resta solo',
#   '見知らぬ人でなく'),
#  ('Q6818188',
#   'María Mercedes Fontecilla Valdivieso',
#   'human',
#   '',
#   'Mercedes Fontecilla',
#   'María Mercedes Fontecilla Valdivieso',
#   'María Mercedes Fontecilla Valdivieso',
#   '',
#   ''),
#  ('Q7828545',
#   "Toucan 'Tecs",
#   'television series',
#   'الصديقان',
#   'The Adventures of Zippi and Zac',
#   '',
#   '',
#   '',
#   ''),
#  ('Q495840',
#   'Little Johnny',
#   'stock character',
#   '',
#   'Jantje',
#   'Jaimito',
#   'blague de Toto',
#   'Pierino',
#   '小さなジョニー'),
#  ('Q153204',
#   'Emilian of Cogolla',
#   'human',
#   'مييان',
#   'Aemilianus von Cogolla',
#   'Millán',
#   'Émilien de la Cogolla',
#   'Emiliano della Cogolla',
#   '聖エミリアヌス'),
#  ('Q778527',
#   'Eros and Civilization',
#   'written work',
#   'الحب والحضارة',
#   'Triebstruktur und Gesellschaft',
#   'Eros y civilización',
#   'Éros et civilisation',
#   'Eros e civiltà',
#   ''),
#  ('Q2625582',
#   'Dumuzid the Fisherman',
#   'human',
#   'دوموزيد الصياد',
#   '',
#   'Dumuzid, el pescador',
#   'Dumuzi le Pêcheur',
#   '',
#   'ドゥムジ (メソポタミア神話)'),
#  ('Q1272037',
#   'Self-portrait at Thirteen',
#   'drawing',
#   '',
#   'Selbstbildnis als Dreizehnjähriger',
#   'autorretrato de Durero',
#   "Autoportrait à l'âge de 13 ans",
#   'Autoritratto a tredici anni',
#   ''),
#  ('Q205524',
#   'Royal Convent of La Encarnación',
#   'monastery',
#   '',
#   'Real Monasterio de la Encarnación',
#   'Real Monasterio de la Encarnación',
#   "monastère de l'Incarnation",
#   'Monastero Reale de la Encarnación',
#   'ラ・エンカルナシオン王立修道院'),
#  ('Q6191409',
#   'Jia Tanchun',
#   'fictional human',
#   '',
#   '',
#   '',
#   'Jia Désir du Printemps',
#   '',
#   '賈探春'),
#  ('Q163689',
#   'Violin Concerto No. 1',
#   'musical work/composition',
#   '',
#   '1. Violinkonzert',
#   'Concierto para violín n.º 1 (Bruch)',
#   'Concerto pour violon nº 1 de Bruch',
#   'Concerto per violino e orchestra (Bruch)',
#   'ヴァイオリン協奏曲第1番 (ブルッフ)'),
#  ('Q2305473',
#   'Bodrum Mosque',
#   'mosque',
#   'جامع بودروم',
#   'Myrelaion',
#   'Mezquita de Bodrum',
#   'mosquée Bodrum',
#   'moschea Bodrum',
#   ''),
#  ('Q333980',
#   'Jumièges Abbey',
#   'abbey',
#   '',
#   'Abtei Jumièges',
#   'Abadía de Jumièges',
#   'abbaye de Jumièges',
#   'abbazia di Jumièges',
#   'ジュミエージュ修道院'),
#  ('Q4115461',
#   'Prophet Joseph',
#   'television series',
#   'يوسف الصديق',
#   'Yousuf e Payambar',
#   'José el Profeta',
#   'Prophète Joseph',
#   '',
#   ''),
#  ('Q739122',
#   'Designing Women',
#   'television series',
#   'ديزاينينغ وومين',
#   'Mann muss nicht sein',
#   '',
#   "Femmes d'affaires et Dames de cœur",
#   'Quattro donne in carriera',
#   '浮気なおしゃれミディ'),
#  ('Q4186950',
#   'The Man in the Moone',
#   'literary work',
#   '',
#   '',
#   'El hombre en la Luna',
#   'L’Homme dans la lune',
#   'The Man in the Moone',
#   '月の男'),
#  ('Q334038',
#   'Marienstatt Abbey',
#   'monastery',
#   '',
#   'Zisterzienserkloster Marienstatt',
#   '',
#   '',
#   '',
#   ''),
#  ('Q9056689',
#   'alphabet pasta',
#   'food',
#   'معكرونة الحروف',
#   'Buchstabennudeln',
#   'pasta de letras',
#   'pâte alimentaire alphabet',
#   'Alfabeto (pasta)',
#   'アルファベットパスタ'),
#  ('Q17512899',
#   'Dan Leno and the Limehouse Golem',
#   'literary work',
#   'دان لينو والغول الجيري',
#   '',
#   '',
#   'Le Golem de Londres',
#   '',
#   '切り裂き魔ゴーレム'),
#  ('Q7446942',
#   'Seishiro Kato',
#   'human',
#   '',
#   'Seishirō Katō',
#   'Seishirō Katō',
#   'Seishirō Katō',
#   'Seishirō Katō',
#   '加藤清史郎'),
#  ('Q1402878',
#   'The Birthday',
#   'hardback',
#   'ذا بيرثداي',
#   '',
#   '',
#   '',
#   'Bāsudei',
#   'バースデイ'),
#  ('Q78635',
#   'Archduke Felix of Austria',
#   'human',
#   'أرشيدوق فيليكس من النمسا',
#   'Felix Habsburg-Lothringen',
#   'Félix de Hasburgo',
#   'Félix de Habsbourg-Lorraine',
#   "Felice d'Asburgo-Lorena",
#   'フェリックス・ハプスブルク＝ロートリンゲン'),
#  ('Q1258295',
#   'Thirty Seconds Over Tokyo',
#   'film',
#   '',
#   'Dreißig Sekunden über Tokio',
#   'Treinta segundos sobre Tokio',
#   'Trente Secondes sur Tokyo',
#   'Missione segreta',
#   '東京上空三十秒'),
#  ('Q3301984',
#   "Man's Best Friend",
#   'film',
#   '',
#   'Der Tod kommt auf vier Pfoten',
#   '',
#   "Max, le meilleur ami de l'homme",
#   '',
#   '未確認生命体 MAX/マックス'),
#  ('Q435016',
#   'Augustus, Elector of Saxony',
#   'human',
#   'أغسطس، ناخب ساكسونيا',
#   'August von Sachsen',
#   'Augusto de Sajonia',
#   'Auguste Ier',
#   'Augusto I di Sassonia',
#   'アウグスト'),
#  ('Q1056344',
#   'Florence Charterhouse',
#   'Carthusian monastery',
#   '',
#   'Certosa San Lorenzo di Galluzzo',
#   'La cartuja de Florencia',
#   'chartreuse de Galluzzo',
#   'certosa di Firenze',
#   ''),
#  ('Q5800956',
#   'Basilica of the National Shrine of Our Lady of Coromoto',
#   'minor basilica',
#   '',
#   'Basilika Unserer Lieben Frau von Coromoto',
#   'Santuario Nacional Nuestra Señora de Coromoto',
#   'basilique Notre-Dame-de-Coromoto',
#   '',
#   ''),
#  ('Q354639',
#   'Minolta SR-mount',
#   'technical standard',
#   '',
#   'Minolta SR-Bajonett',
#   '',
#   'Monture Minolta SR',
#   'attacco Minolta SR',
#   ''),
#  ('Q210210',
#   'Concerto for Piano and Orchestra no. 2 in F minor, op. 21',
#   'musical work/composition',
#   '',
#   '2. Klavierkonzert',
#   'Concierto para piano n.º 2',
#   'Concerto pour piano nº 2 de Chopin',
#   'Concerto per pianoforte n. 2 op. 21',
#   'ピアノ協奏曲第2番'),
#  ('Q324119',
#   'Volkenroda Abbey',
#   'monastery',
#   '',
#   'Zisterzienserkloster Volkenroda',
#   '',
#   'monastère de Volkenroda',
#   '',
#   ''),
#  ('Q17027987',
#   'The Rogue Prince',
#   'literary work',
#   'الأمير المارق',
#   '',
#   'El Príncipe Pícaro',
#   '',
#   '',
#   '王弟'),
#  ('Q280872',
#   'Timon of Phlius',
#   'human',
#   '',
#   'Timon von Phleius',
#   'Timón el Silógrafo',
#   'Timon de Phlionte',
#   'Timone di Fliunte',
#   'プリウスのティモン'),
#  ('Q322678',
#   'Our Lady of Altötting',
#   'chapel',
#   '',
#   'Gnadenkapelle',
#   'Capilla de Nuestra Señora de Altötting',
#   "sanctuaire Notre-Dame d'Altötting",
#   'cappella delle Grazie',
#   'アルテッティングの聖母巡礼聖堂'),
#  ('Q919407',
#   'wicked fairy godmother',
#   'folklore character',
#   '',
#   'Karabossa',
#   '',
#   'fée Carabosse',
#   'Fata cattiva',
#   ''),
#  ('Q5117080',
#   'Church of Saint Anthony of the Germans',
#   'Catholic church building',
#   '',
#   '',
#   'Iglesia de San Antonio de los Alemanes',
#   'église St Antoine des Allemands',
#   "chiesa di Sant'Antonio degli Alemanni",
#   'サン・アントニオ・デ・ロス・ポルトゥゲーセス聖堂'),
#  ('Q19320',
#   'The Little Devil',
#   'film',
#   '',
#   'Ein himmlischer Teufel',
#   'Il piccolo diavolo',
#   'Le Petit Diable',
#   'Il piccolo diavolo',
#   ''),
#  ('Q235128',
#   'Infanta María de las Mercedes, Countess of Barcelona',
#   'human',
#   'الأميرة ماريا مرسيديس دي الصقليتين',
#   'María de las Mercedes de Borbón y Orléans',
#   'María de las Mercedes de Borbón',
#   'María de las Mercedes de Bourbon-Siciles',
#   'Maria di Borbone',
#   'マリア・デ・ラス・メルセデス・デ・ボルボーン＝ドス・シシリアス'),
#  ('Q246511',
#   'Symphony No. 6',
#   'musical work/composition',
#   '',
#   '6. Sinfonie',
#   'Sinfonía n.º 6',
#   'Symphonie nº 6 de Prokofiev',
#   "Sinfonia n. 6 (Prokof'ev)",
#   '交響曲第6番'),
#  ('Q3230961',
#   'Underworld U.S.A.',
#   'film',
#   '',
#   'Alles auf eine Karte',
#   '',
#   'Les Bas-fonds new-yorkais',
#   'La vendetta del gangster',
#   '殺人地帯U・S・A'),
#  ('Q641315',
#   'Spirit: Stallion of the Cimarron',
#   'animated film',
#   'سبيريت: حصان من سيمارون',
#   'Spirit – Der wilde Mustang',
#   'Spirit: el corcel indomable',
#   "Spirit, l'étalon des plaines",
#   'Spirit - Cavallo selvaggio',
#   'スピリット'),
#  ('Q3687260',
#   'Consider the Lobster',
#   'written work',
#   '',
#   '',
#   'Hablemos de langostas',
#   'Considérations sur le homard',
#   "Considera l'aragosta",
#   ''),
#  ('Q3772823',
#   'Wang Xifeng',
#   'fictional human',
#   '',
#   '',
#   '',
#   'Wang Phénix triomphal',
#   '',
#   '王熙鳳'),
#  ('Q2551859',
#   'Miraflores Charterhouse',
#   'Carthusian monastery',
#   '',
#   'Kartause Miraflores',
#   'Cartuja de Santa María de Miraflores',
#   'chartreuse Santa María de Miraflores',
#   'certosa di Miraflores',
#   ''),
#  ('Q263203',
#   'red cabbage',
#   'taxon',
#   'ملفوف أحمر',
#   'Rotkohl',
#   'col lombarda',
#   'chou rouge',
#   'cavolo rosso',
#   '赤キャベツ'),
#  ('Q31190329',
#   'Taksim Mosque',
#   'mosque',
#   'مسجد تقسيم',
#   'Taksim-Moschee',
#   '',
#   '',
#   'Moschea di Taksim',
#   'タクスィムモスク'),
#  ('Q2042566',
#   'Farmer in the Sky',
#   'literary work',
#   '',
#   'Pioniere im Weltall',
#   'El granjero de las estrellas',
#   'Pommiers dans le ciel',
#   'Pionieri dello spazio',
#   'ガニメデの少年'),
#  ('Q296555',
#   'Philippe, Duke of Orléans',
#   'human',
#   'فيليب الأول، دوق أورليان',
#   'Philippe I. de Bourbon, duc d’Orléans',
#   'Felipe I de Orleans',
#   "Philippe d'Orléans",
#   'Filippo I di Borbone-Orléans',
#   'フィリップ1世'),
#  ('Q225373',
#   'Kykkos Monastery',
#   'monastery',
#   'دير كيكوس',
#   'Kloster Kykkos',
#   'Monasterio de Kikkos',
#   'monastère de Kykkos',
#   'Monastero di Kykkos',
#   'キッコス修道院'),
#  ('Q1091065',
#   'Weirdsister College',
#   'television series',
#   '',
#   'Die Hochschule der Komischen Schwestern',
#   '',
#   '',
#   '',
#   'ウィアードシスターズ・カレッジ'),
#  ('Q333912',
#   'Floreffe Abbey',
#   'monastery',
#   '',
#   'Abtei Floreffe',
#   '',
#   'abbaye de Floreffe',
#   '',
#   ''),
#  ('Q1105407',
#   'Curious George',
#   'fictional monkey',
#   '',
#   'Coco – Der neugierige Affe',
#   'Jorge el curioso',
#   'Georges le singe',
#   '',
#   'ひとまねこざる'),
#  ('Q59346',
#   'The Mortal Instruments: City of Bones',
#   'film',
#   'الأدوات المميتة: مدينة العظام',
#   'Chroniken der Unterwelt – City of Bones',
#   'Cazadores de sombras: Ciudad de hueso',
#   'The Mortal Instruments : La Cité des ténèbres',
#   'Shadowhunters - Città di ossa',
#   'シャドウハンター'),
#  ('Q1994481',
#   'Bullet Bill',
#   'fictional species',
#   '',
#   'Kugel Willi',
#   'Bill Bala',
#   '',
#   'Pallottolo Bill',
#   'キラー (ゲームキャラクター)'),
#  ('Q940186',
#   'Breakheart Pass',
#   'film',
#   '',
#   'Nevada Pass',
#   'Nevada Express',
#   'Le Solitaire de Fort Humboldt',
#   'Io non credo a nessuno',
#   '軍用列車'),
#  ('Q85808226',
#   "The Queen's Gambit",
#   'miniseries',
#   'مناورة الملكة',
#   'Das Damengambit',
#   'Gambito de Reina',
#   'Le Jeu de la dame',
#   'La regina degli scacchi',
#   'クイーンズ・ギャンビット (ドラマ)'),
#  ('Q3235392',
#   'The Rediscovery of Man',
#   'written work',
#   '',
#   '',
#   '',
#   "Les Seigneurs de l'instrumentalité",
#   '',
#   ''),
#  ('Q2471799',
#   'Ketchaoua Mosque',
#   'mosque',
#   'جامع كتشاوة',
#   'Ketschawa-Moschee',
#   'Mezquita de Ketchaoua',
#   'mosquée Ketchaoua',
#   'moschea Ketchaoua',
#   ''),
#  ('Q105620963',
#   'I am Jalaliddin',
#   'television series',
#   'منديرمان جلال الدين',
#   'Mendirman Jaloliddin',
#   '',
#   '',
#   '',
#   ''),
#  ('Q1265755',
#   'The Theory of the Leisure Class',
#   'written work',
#   'نظرية الطبقة المترفة',
#   'Theorie der feinen Leute',
#   'Teoría de la clase ociosa',
#   'Théorie de la classe de loisir',
#   '',
#   '有閑階級の理論'),
#  ('Q1758561',
#   'Serenade for Strings',
#   'musical work/composition',
#   '',
#   '',
#   'Serenata para cuerdas (Dvořák)',
#   'Sérénade pour cordes',
#   'Serenata per archi',
#   '弦楽セレナーデ'),
#  ('Q2891563',
#   'Batman & Dracula trilogy',
#   'graphic novel',
#   'ثلاثية باتمان ودراكولا',
#   '',
#   'Batman & Drácula: lluvia roja',
#   'Batman et Dracula : Pluie de sang',
#   'Batman: Vampiro',
#   ''),
#  ('Q833178',
#   'Schäftlarn Abbey',
#   'abbey',
#   '',
#   'Prämonstratenserstift Schäftlarn',
#   'Abadía de Schäftlarn',
#   'abbaye de Schäftlarn',
#   '',
#   'シェフトラルン修道院'),
#  ('Q1645774',
#   'House Greyjoy',
#   'fictional noble family',
#   'آل غريجوي',
#   '',
#   'Casa Greyjoy',
#   '',
#   'Casa Greyjoy',
#   ''),
#  ('Q820238',
#   '21 Hours at Munich',
#   'film',
#   '21 ساعة في ميونخ',
#   'Die 21 Stunden von München',
#   '21 horas en Munich',
#   'Les 21 Heures de Munich',
#   '21 ore a Monaco',
#   'テロリスト・黒い九月'),
#  ('Q3477975',
#   'Sixteen Waltzes, Op. 39',
#   'musical work/composition',
#   '',
#   'Sechzehn Walzer für Klavier',
#   'Dieciséis valses, op. 39',
#   'Seize valses pour piano à quatre mains',
#   'Sedici valzer',
#   'ワルツ集 (ブラームス)'),
#  ('Q1048557',
#   "Maeterlinck's Blue Bird: Tyltyl and Mytyl's Adventurous Journey",
#   'anime television series',
#   '',
#   'Mêterurinku no aoi tori: Chiruchiru Michiru no bôken ryokô',
#   '',
#   "L'Oiseau bleu",
#   "L'uccellino azzurro",
#   'メーテルリンクの青い鳥 チルチルミチルの冒険旅行'),
#  ('Q1670321',
#   'St. George Utah Temple',
#   'temple',
#   '',
#   'St.-George-Utah-Tempel',
#   'Templo de St. George',
#   'temple mormon de Saint George',
#   '',
#   ''),
#  ('Q3490244',
#   'Cello Sonata No. 2',
#   'musical work/composition',
#   '',
#   '',
#   '',
#   'Sonate pour violoncelle et piano nº 2',
#   '',
#   'チェロソナタ第2番 (メンデルスゾーン)'),
#  ('Q2820392',
#   "St. Joseph's Abbey",
#   'Trappist monastery',
#   '',
#   'Trappistenabtei Spencer',
#   'abadía de San José',
#   'abbaye Saint-Joseph',
#   '',
#   'セントジョゼフ修道院'),
#  ('Q6167871',
#   'The Spiral Road',
#   'film',
#   '',
#   'Am Schwarzen Fluss',
#   'Camino de la jungla',
#   "L'Homme de Bornéo",
#   'La strada a spirale',
#   ''),
#  ('Q3202654',
#   'The Female Man',
#   'literary work',
#   '',
#   'Planet der Frauen',
#   'El hombre hembra',
#   "L'Autre Moitié de l'homme",
#   '',
#   'フィーメール・マン'),
#  ('Q214050',
#   'Frederick V, Landgrave of Hesse-Homburg',
#   'human',
#   '',
#   'Friedrich V.',
#   'Federico V de Hesse-Homburg',
#   'Frédéric V de Hesse-Hombourg',
#   "Federico V d'Assia-Homburg",
#   'フリードリヒ5世'),
#  ('Q1245538',
#   'Dormition Abbey',
#   'abbey',
#   'كنيسة رقاد السيدة العذراء',
#   'Dormitio-Abtei',
#   'abadía de Hagia María',
#   'abbaye de la Dormition de Jérusalem',
#   'basilica della Dormizione di Maria',
#   '聖母昇天修道院'),
#  ('Q1215227',
#   'The War Lord',
#   'film',
#   '',
#   'Die Normannen kommen',
#   'El señor de la guerra',
#   'Le Seigneur de la guerre',
#   'Il principe guerriero',
#   '大将軍'),
#  ('Q1156068',
#   'Violin Concerto',
#   'musical work/composition',
#   '',
#   'Violinkonzert',
#   'Concierto para violín',
#   'Concerto pour violon de Brahms',
#   'Concerto per violino e orchestra',
#   'ヴァイオリン協奏曲'),
#  ('Q107392376',
#   'The Longest Night',
#   'television series',
#   'الليلة الأطول',
#   'Die längste Nacht',
#   'La noche más larga',
#   'La nuit sera longue',
#   '',
#   ''),
#  ('Q435978',
#   'Albert IV, Duke of Austria',
#   'human',
#   'ألبرت الرابع، دوق النمسا',
#   'Albrecht IV.',
#   'Alberto IV de Austria',
#   "Albert IV d'Autriche",
#   "Alberto IV d'Asburgo",
#   'アルブレヒト4世'),
#  ('Q1635605',
#   'Cuthbert Calculus',
#   'fictional human',
#   '',
#   'Professor Bienlein',
#   'Silvestre Tornasol',
#   'Professeur Tournesol',
#   'Professor Trifone Girasole',
#   'ビーカー教授'),
#  ('Q110920339',
#   'Into the Wind',
#   'film',
#   '',
#   'Hart am Wind',
#   '',
#   '',
#   "Le onde dell'amore",
#   ''),
#  ('Q6945142',
#   'My Cat from Hell',
#   'television program',
#   '',
#   'Der Katzenflüsterer',
#   'Mi Gato Endemoniado',
#   '',
#   'Il mio gatto è indemoniato',
#   '猫ヘルパー 猫のしつけ教えます'),
#  ('Q997715',
#   'Monastery of St Saviour',
#   'friary',
#   'دير المخلص',
#   'Salvatorkirche',
#   'Monasterio de San Salvador',
#   '',
#   'Convento di San Salvatore',
#   '聖救世主修道院'),
#  ('Q1197765',
#   'The origin of the family, private property and the state',
#   'literary work',
#   'أصل العائلة والملكية الخاصة والدولة',
#   'Der Ursprung der Familie, des Privateigentums und des Staats',
#   'El origen de la familia, la propiedad privada y el Estado',
#   "L'Origine de la famille, de la propriété privée et de l'État",
#   "L'origine della famiglia, della proprietà privata e dello Stato",
#   '家族・私有財産・国家の起源'),
#  ('Q2497079',
#   'Around the World Under the Sea',
#   'film',
#   '',
#   'Unter Wasser rund um die Welt',
#   'La vuelta al mundo bajo el mar',
#   'Le Tour du monde sous les mers',
#   '',
#   '海底世界一周'),
#  ('Q96409754',
#   'They Both Die at the End',
#   'literary work',
#   '',
#   'Am Ende sterben wir sowieso',
#   'Al final mueren los dos',
#   'Et ils meurent tous les deux à la fin',
#   '',
#   ''),
#  ('Q2597616', 'XT bus', 'bus', '', 'XT-Bus-Architektur', '', '', '', 'XTバス'),
#  ('Q3899527',
#   "Please Don't Eat the Daisies",
#   'television series',
#   '',
#   'Unser trautes Heim',
#   '',
#   '',
#   'Per favore non mangiate le margherite',
#   'ぼくら1匹6人'),
#  ('Q63993138',
#   'Fully Automated Luxury Communism',
#   'literary work',
#   '',
#   '',
#   'Comunismo de lujo totalmente automatizado',
#   '',
#   '',
#   ''),
#  ('Q462917',
#   'Konstantin Tih',
#   'human',
#   '',
#   'Konstantin Tich Asen',
#   'Constantino Tij',
#   'Konstantin Ier Tikh Asen',
#   'Costantino I di Bulgaria',
#   'コンスタンティン・ティフ'),
#  ('Q12204304',
#   'Mosque of the Prophet Yunus',
#   'mosque',
#   'جامع النبي يونس',
#   'Prophet-Jona-Moschee',
#   '',
#   '',
#   'Nebi Yunus',
#   ''),
#  ('Q1263875',
#   'Hell Drivers',
#   'film',
#   '',
#   'Duell am Steuer',
#   'Ruta infernal',
#   "Train d'enfer",
#   "I piloti dell'inferno",
#   ''),
#  ('Q523691',
#   'Schleswig Cathedral',
#   'Lutheran cathedral',
#   'كاتدرائية شلسفيع',
#   'Schleswiger Dom',
#   'Catedral de Schleswig',
#   'cathédrale de Schleswig',
#   'Cattedrale di Schleswig',
#   'シュレースヴィヒ聖堂'),
#  ('Q1967977',
#   'National Academy of Sciences of Belarus',
#   'academy of sciences',
#   'الأكاديمية الوطنية للعلوم في بيلاروسيا',
#   'Nationale Akademie der Wissenschaften von Belarus',
#   'Academia Nacional de Ciencias de Bielorrusia',
#   'Académie nationale des sciences de Biélorussie',
#   '',
#   'ベラルーシ国立科学アカデミー'),
#  ('Q3714685',
#   'Run, Joe, Run',
#   'television series',
#   '',
#   '',
#   '',
#   'Joe le fugitif',
#   'Dove corri Joe?',
#   'がんばれ!名犬ジョー'),
#  ('Q168309',
#   'The Village in the Treetops',
#   'literary work',
#   'القرية اللطيفة',
#   'Das Dorf in den Lüften',
#   'El pueblo aéreo',
#   'Le Village aérien',
#   'Il villaggio aereo',
#   '空中の村'),
#  ('Q1572457',
#   'Zal Mahmud Pasha Mosque',
#   'congregational mosque',
#   'جامع زال محمود باشا',
#   'Zal-Mahmud-Pascha-Moschee',
#   '',
#   '',
#   'moschea di Zal Mahmud Pascià',
#   'ザール・マフムード・パシャ・ジャーミイ'),
#  ('Q44064',
#   'sockeye salmon',
#   'taxon',
#   'سلمون أحمر',
#   'Rotlachs',
#   'salmón rojo',
#   'Saumon rouge',
#   'salmone rosso',
#   'ベニザケ'),
#  ('Q3384226',
#   'Baby Cakes',
#   'television film',
#   '',
#   '',
#   '',
#   'Une fille à croquer',
#   '',
#   ''),
#  ('Q4354219',
#   '99 and 44/100% Dead',
#   'film',
#   '',
#   'König Ballermann',
#   '99,44% muerto',
#   'Refroidi à 99%',
#   'Attento sicario: Crown è in caccia',
#   '殺し屋ハリー/華麗なる挑戦'),
#  ('Q16271791',
#   'All Flesh is Grass',
#   'literary work',
#   '',
#   '',
#   '',
#   'Les Fleurs pourpres',
#   'Il villaggio dei fiori porpurei',
#   ''),
#  ('Q160539',
#   'Princess Helena of the United Kingdom',
#   'human',
#   'هيلينا أوغستا فكتوريا',
#   'Helena von Großbritannien und Irland',
#   'Elena del Reino Unido',
#   'Helena du Royaume-Uni',
#   'Elena di Sassonia-Coburgo-Gotha',
#   'ヘレナ'),
#  ('Q339425',
#   'Random Harvest',
#   'film',
#   'حصاد عشوائي',
#   'Gefundene Jahre',
#   'Niebla en el pasado',
#   'Prisonniers du passé',
#   'Prigionieri del passato',
#   '心の旅路'),
#  ('Q1037282',
#   'Great Ming Code',
#   'code of law',
#   '',
#   '',
#   '',
#   'Grand code des Mings',
#   '',
#   '大明律'),
#  ('Q2436441',
#   'Riquet with the Tuft',
#   'literary work',
#   'riquer a la houppe',
#   'Riquet mit dem Schopf',
#   'Riquete el del Copete',
#   'Riquet à la houppe',
#   'Enrichetto dal ciuffo',
#   ''),
#  ('Q333840',
#   'Brauweiler Abbey',
#   'monastery',
#   '',
#   'Benediktinerabtei Brauweiler',
#   '',
#   'abbaye de Brauweiler',
#   '',
#   'ブラウヴァイラー修道院'),
#  ('Q2204718',
#   'The Shepheardes Calender',
#   'poetry',
#   '',
#   '',
#   '',
#   '',
#   'Il calendario del pastore',
#   '羊飼いの暦'),
#  ('Q3230889',
#   'A Town Called Bastard',
#   'film',
#   '',
#   'Kein Requiem für San Bastardo',
#   'Una ciudad llamada Bastarda',
#   'Les Brutes dans la ville',
#   'Una città chiamata bastarda',
#   '荒野のライフル'),
#  ('Q7676476',
#   'Taitei no Ken',
#   'film',
#   '',
#   '',
#   'The Sword of Alexander',
#   '',
#   '',
#   '大帝の剣'),
#  ('Q18747380',
#   'The Beauty and the Beast',
#   'miniseries',
#   '',
#   'Die Legende einer unsterblichen Liebe',
#   'La Bella y la Bestia',
#   '',
#   'La bella e la bestia',
#   ''),
#  ('Q1534095',
#   'Goethe Monument',
#   'monument',
#   '',
#   'Goethe-Denkmal',
#   '',
#   '',
#   'Monumento a Goethe',
#   ''),
#  ('Q733984',
#   'Pope Cyril VI of Alexandria',
#   'human',
#   'كيرلس السادس',
#   'Kirellos VI.',
#   'Cirilo VI',
#   "Cyrille VI d'Alexandrie",
#   'Cirillo VI di Alessandria',
#   'キリロス6世'),
#  ('Q149405',
#   'Bearded Seal',
#   'taxon',
#   'عجل البحر الملتحي',
#   'Bartrobbe',
#   'Erignathus barbatus',
#   'Phoque barbu',
#   'Erignathus barbatus',
#   'アゴヒゲアザラシ'),
#  ('Q2499675',
#   'Tales from Earthsea',
#   'literary work',
#   '',
#   'Das Vermächtnis von Erdsee',
#   'Cuentos de Terramar',
#   'Contes de Terremer',
#   'Leggende di Earthsea',
#   'ドラゴンフライ アースシーの五つの物語'),
#  ('Q164634',
#   'Symphony No. 10',
#   'musical work/composition',
#   '',
#   '10. Sinfonie',
#   'Sinfonía n.º 10',
#   'Symphonie nº 10 de Mahler',
#   'Sinfonia n. 10',
#   '交響曲第10番'),
#  ('Q490102',
#   'Valday Iversky Monastery',
#   'Eastern Orthodox monastery',
#   '',
#   'Iwerski-Kloster',
#   'Monasterio Iversky de Valdai',
#   'monastère Iverski de Valdaï',
#   '',
#   ''),
#  ('Q2535473',
#   'The Lunch',
#   'painting',
#   'مأدبة الغداء',
#   'Drei Männer am Tisch',
#   'El almuerzo',
#   'Trois hommes à table, le déjeuner',
#   'Pranzo',
#   '昼食'),
#  ('Q8464452',
#   "Philosopher's Stone",
#   'magical object in Harry Potter',
#   '',
#   'Stein der Weisen',
#   'piedra filosofal',
#   'pierre philosophale',
#   'pietra filosofale',
#   '賢者の石'),
#  ('Q137741',
#   'Police Woman',
#   'television series',
#   '',
#   'Make-up und Pistolen',
#   'La mujer policía',
#   'Sergent Anderson',
#   'Pepper Anderson - Agente speciale',
#   '女刑事ペパー'),
#  ('Q78591',
#   'Archduke Maximilian Eugen of Austria',
#   'human',
#   'الأرشيدوق ماكسيمليان يوجين من النمسا',
#   'Maximilian Eugen von Österreich',
#   'Maximiliano Eugenio de Austria',
#   "Maximilien Eugène d'Autriche",
#   "Massimiliano Eugenio d'Asburgo-Lorena",
#   'マクシミリアン・オイゲン・フォン・エスターライヒ'),
#  ('Q297547',
#   'Alexander I of Serbia',
#   'human',
#   'ألكسندر الأول ملك صربيا',
#   'Aleksandar Obrenović',
#   'Alejandro I de Serbia',
#   'Alexandre Ier de Serbie',
#   'Alessandro I di Serbia',
#   'アレクサンダル1世'),
#  ('Q2391306',
#   'The Fountain of Bakhchisaray',
#   'narrative poetry',
#   '',
#   'Die Fontäne von Baktschi-Sarai',
#   '',
#   'La Fontaine de Bakhtchisaraï',
#   'La fontana di Bachčisaraj',
#   'バフチサライの泉'),
#  ('Q7755297',
#   'The Orchid Thief',
#   'literary work',
#   '',
#   '',
#   '',
#   '',
#   'Il ladro di orchidee',
#   'ジョン・ラロシュ'),
#  ('Q55611675',
#   'Fire and Blood',
#   'literary work',
#   'النار والدم (رواية)',
#   '',
#   'Fuego y sangre',
#   'Feu et Sang',
#   'Fuoco e sangue',
#   ''),
#  ('Q168657',
#   'Albert I of Saxony',
#   'human',
#   '',
#   'Albert von Sachsen',
#   'Alberto I de Sajonia',
#   'Albert Ier de Saxe',
#   'Alberto di Sassonia',
#   'アルベルト'),
#  ('Q1249413',
#   'I Spy',
#   'television series',
#   '',
#   'Tennisschläger und Kanonen',
#   '',
#   'Les Espions',
#   'Le spie',
#   'アイ・スパイ'),
#  ('Q897215',
#   'Lichtenthal Abbey',
#   'Cistercian nunnery',
#   '',
#   'Kloster Lichtenthal',
#   '',
#   'abbaye de Lichtenthal',
#   'Abbazia di Lichtenthal',
#   ''),
#  ('Q467062',
#   'Judah Leon Abravanel',
#   'human',
#   '',
#   'Jehuda ben Isaak Abravanel',
#   'León Hebreo',
#   "Léon l'Hébreu",
#   'Leone Ebreo',
#   'イェフダ・レオネ・アブラバネル'),
#  ('Q1151528',
#   'A Case of Identity',
#   'literary work',
#   'قضية هوية',
#   '',
#   'Un caso de identidad',
#   "Une affaire d'identité",
#   'Un caso di identità',
#   '花婿失踪事件'),
#  ('Q647070',
#   'Clairvaux Abbey',
#   'Cistercian monastery',
#   '',
#   'Kloster Clairvaux',
#   'abadía de Claraval',
#   'abbaye de Clairvaux',
#   'abbazia di Clairvaux',
#   'クレルヴォー修道院'),
#  ('Q767819',
#   'Play It Again, Sam',
#   'film',
#   '',
#   'Mach’s noch einmal, Sam',
#   'Sueños de un seductor',
#   'Tombe les filles et tais-toi',
#   'Provaci ancora, Sam',
#   'ボギー!俺も男だ'),
#  ('Q240927',
#   'Medius of Larissa',
#   'human',
#   '',
#   'Medios von Larissa',
#   'Medio de Larisa',
#   'Médios de Larissa',
#   'Medio di Larissa',
#   ''),
#  ('Q10338664',
#   'The ABC of Communism',
#   'literary work',
#   '',
#   '',
#   'El ABC del comunismo',
#   "L'ABC du communisme",
#   "L'ABC del comunismo",
#   '共産主義のABC'),
#  ('Q3005861',
#   'Mood Indigo',
#   'film',
#   'مزاج نيلي',
#   'Der Schaum der Tage',
#   'La Espuma del Día',
#   "L'Écume des jours",
#   "L'écume des jours",
#   'ムード・インディゴ うたかたの日々'),
#  ('Q390914',
#   'Stopped on Track',
#   'film',
#   'توقف بين المحطات',
#   'Halt auf freier Strecke',
#   'Parada en plena vía',
#   'Pour lui',
#   'Halt auf freier Strecke',
#   ''),
#  ('Q2283127',
#   'The Book of Good Love',
#   'literary work',
#   'كتاب الحب الفاضل',
#   '',
#   'Libro de buen amor',
#   'Libro de Buen Amor',
#   'Libro de Buen Amor',
#   'よき愛の書'),
#  ('Q2307647',
#   'Palace of Facets',
#   'palace',
#   '',
#   'Facettenpalast',
#   'Palacio de las Facetas',
#   'palais à Facettes',
#   'Palazzo delle Faccette',
#   'グラノヴィータヤ宮殿'),
#  ('Q2956167',
#   'A Song for Lya and Other Stories',
#   'short story collection',
#   'أغنية من أجل ليا',
#   '',
#   'Una canción para Lya',
#   'Chanson pour Lya',
#   '',
#   ''),
#  ('Q6037603',
#   "Inside Hitler's Bunker",
#   'literary work',
#   '',
#   'Der Untergang: Hitler und das Ende des Dritten Reiches',
#   '',
#   '',
#   '',
#   'ヒトラー 最期の12日間'),
#  ('Q969022',
#   'Genesius of Rome',
#   'legendary figure',
#   'جينيسيوس',
#   'Genesius von Rom',
#   'Ginés de Roma',
#   'Genès de Rome',
#   'Genesio di Roma',
#   ''),
#  ('Q378702',
#   'Pepin II of Aquitaine',
#   'human',
#   '',
#   'Pippin II.',
#   'Pipino II de Aquitania',
#   "Pépin II d'Aquitaine",
#   'Pipino II di Aquitania',
#   'ピピン2世'),
#  ('Q2228568',
#   "Ichijo's Wet Lust",
#   'film',
#   '',
#   'Sayuri, die Stripperin',
#   'Wet Desire',
#   'Sayuri, strip-teaseuse',
#   '',
#   '一条さゆり\u3000濡れた欲情'),
#  ('Q2707472',
#   'Super Friends',
#   'animated television series',
#   '',
#   'Das Powerteam – Superman und Co.',
#   'Súper amigos',
#   'Le Plein de super',
#   'I Superamici',
#   'スーパーフレンズ'),
#  ('Q1955986',
#   'Mother Svea',
#   'national personification',
#   'الأم سفيا',
#   'Mutter Svea',
#   'Madre Svea',
#   'Mère Svea',
#   'Madre Svea',
#   'モダー・スヴェア'),
#  ('Q1020717',
#   'How Do They Do It?',
#   'television program',
#   'كيف يفعلون ذلك؟',
#   'Technikwelten',
#   '¿Cómo lo hacen?',
#   '',
#   'Marchio di fabbrica',
#   ''),
#  ('Q97278509',
#   'Down to Earth with Zac Efron',
#   'television series',
#   '',
#   'Um die Welt mit Zac Efron',
#   'Zac Efron: con los pies sobre la tierra',
#   '',
#   'Zac Efron: con i piedi per terra',
#   ''),
#  ('Q73569',
#   'history of Gaza',
#   'history of a city',
#   'تاريخ غزة',
#   '',
#   'historia de Gaza',
#   'histoire de Gaza antique',
#   'storia di Gaza',
#   ''),
#  ('Q389473',
#   'Princess Elizabeth Albertine of Saxe-Hildburghausen',
#   'human',
#   'الأميرة إليزابيث ألبرتين من ساكس-هيلدبورغهاوزن',
#   'Elisabeth Albertine von Sachsen-Hildburghausen',
#   'Isabel Albertina de Sajonia-Hildburghausen',
#   'Élisabeth-Albertine de Saxe-Hildburghausen',
#   'Elisabetta Albertina di Sassonia-Hildburghausen',
#   'エリザベート・アルベルティーネ・フォン・ザクセン＝ヒルトブルクハウゼン'),
#  ('Q2935263',
#   'The Nun',
#   'film',
#   '',
#   'Die Nonne',
#   'La religiosa',
#   'La Religieuse',
#   'La religiosa',
#   ''),
#  ('Q3024931',
#   'Let It Ride',
#   'film',
#   'تركه يركب',
#   'Alles auf Sieg',
#   'A rienda suelta',
#   'Deux Dollars sur un tocard',
#   '',
#   'のるかそるか'),
#  ('Q1494326',
#   'Valldemossa Charterhouse',
#   'Carthusian monastery',
#   '',
#   'Kartause von Valldemossa',
#   'Cartuja de Valldemosa',
#   'chartreuse de Valldemossa',
#   '',
#   'バルデモーサ・カルトゥジオ会修道院'),
#  ('Q21059232',
#   'Five Children',
#   'television series',
#   'خمسة أطفال',
#   '',
#   'Cinco niños',
#   '',
#   '',
#   'ドキドキ再婚ロマンス〜子どもが5人'),
#  ('Q812981',
#   'Answering the Question: What Is Enlightenment?',
#   'literary work',
#   'ما هو التنوير؟',
#   'Beantwortung der Frage: Was ist Aufklärung?',
#   'Respuesta a la pregunta: ¿Qué es Ilustración?',
#   "Qu'est-ce que les Lumières ?",
#   "Risposta alla domanda: che cos'è l'Illuminismo?",
#   ''),
#  ('Q233954',
#   'coat of arms of Antigua and Barbuda',
#   'national coat of arms',
#   'شعار أنتيغوا وباربودا',
#   'Wappen von Antigua und Barbuda',
#   'Escudo de Antigua y Barbuda',
#   "Armoiries d'Antigua-et-Barbuda",
#   'stemma di Antigua e Barbuda',
#   'アンティグア・バーブーダの国章'),
#  ('Q3496170',
#   'The Story of a Mother',
#   'fairy tale',
#   'مجلة الرسالة/العدد 361/القصص',
#   '',
#   'Historia de una madre',
#   '',
#   'Storia di una mamma',
#   'ある母親の物語'),
#  ('Q1031890',
#   'Piano Sonata in B Minor',
#   'musical work/composition',
#   '',
#   'Klaviersonate h-Moll',
#   'Sonata en si menor (Liszt)',
#   'Sonate pour piano en si mineur de Liszt',
#   'Sonata in si minore',
#   'ピアノソナタ (リスト)'),
#  ('Q381632',
#   'Egmond Abbey',
#   'abbey',
#   '',
#   'Kloster Egmond',
#   'abadía de Egmond',
#   "abbaye d'Egmont",
#   '',
#   'エグモント修道院'),
#  ('Q1968407',
#   'Basilica of the National Shrine of the Assumption of the Blessed Virgin Mary',
#   'Catholic cathedral',
#   '',
#   'Nationalheiligtum Basilika Mariä Himmelfahrt',
#   'basílica del Santuario Nacional de la Asunción de la Bienaventurada Virgen María',
#   "basilique de l'Assomption",
#   'concattedrale di Baltimora',
#   ''),
#  ('Q550346',
#   'Cathedral of Saint Demetrius',
#   'Eastern Orthodox church building',
#   '',
#   'Demetrios-Kathedrale (Wladimir)',
#   'Catedral de San Demetrio de Vladímir',
#   'cathédrale Saint-Dimitri',
#   'cattedrale di San Demetrio',
#   'ドミトリエフスキー聖堂'),
#  ('Q2639259',
#   'Prince Henry, Count of Bardi',
#   'human',
#   'الأمير إنريكو، كونت بردي',
#   'Henri de Bourbon-Parma',
#   'Enrique de Borbón-Parma, conde de Bardi',
#   'Henri de Bourbon-Parme',
#   'Enrico Carlo di Borbone-Parma',
#   'エンリコ・ディ・ボルボーネ＝パルマ'),
#  ('Q1094447',
#   'House Ordos',
#   'fictional noble family',
#   '',
#   '',
#   '',
#   'maison Ordos',
#   'Casa Ordos',
#   ''),
#  ('Q855877',
#   'impulse drive',
#   'fictional technology',
#   '',
#   'Impulsantrieb',
#   'motor de impulso',
#   'moteur à impulsion',
#   'Propulsione a impulso',
#   ''),
#  ('Q1048249',
#   'Italian folk music',
#   'music by ethnic group',
#   'موسيقى شعبية إيطالية',
#   'italienische Volksmusik',
#   '',
#   'musique traditionnelle italienne',
#   'musica tradizionale italiana',
#   ''),
#  ('Q515572',
#   'For Whom the Bell Tolls',
#   'film',
#   'لمن تقرع له الأجراس',
#   'Wem die Stunde schlägt',
#   'Por quién doblan las campanas',
#   'Pour qui sonne le glas',
#   'Per chi suona la campana',
#   '誰が為に鐘は鳴る'),
#  ('Q3225607',
#   "The Mummy's Foot",
# ...
#   '',
#   ''),
#  ('Q1540481',
#   'Highway to Hell',
#   'film',
#   '',
#   'Highway zur Hölle',
#   'Autopista al infierno',
#   "L'Autoroute de l'enfer",
#   "Autostrada per l'inferno",
#   '地獄のハイウェイ'),
#  ('Q97933169', 'Darcey Silva', 'human', '', 'Silva Twins', '', '', '', ''),
#  ('Q163524',
#   'Symphony No. 1',
#   'musical work/composition',
#   '',
#   '1. Sinfonie',
#   'Sinfonía n.º 1',
#   'Symphonie nº 1 de Bruckner',
#   'Sinfonia n. 1',
#   '交響曲第1番 (ブルックナー)'),
#  ('Q1331849',
#   'Love Me Tonight',
#   'film',
#   'أحبني الليلة',
#   'Schönste, liebe mich',
#   'Ámame esta noche',
#   'Aimez-moi ce soir',
#   'Amami stanotte',
#   '今晩愛して頂戴ナ'),
#  ('Q48977465',
#   'Little Fires Everywhere',
#   'literary work',
#   'نيران صغيرة في كل مكان (رواية)',
#   'Kleine Feuer überall',
#   'Pequeños fuegos por todas partes',
#   'La Saison des feux',
#   'Tanti piccoli fuochi',
#   ''),
#  ('Q1248625',
#   'The Mod Squad',
#   'television series',
#   '',
#   'Twen-Police',
#   '',
#   'La Nouvelle Équipe',
#   'Mod Squad, i ragazzi di Greer',
#   'モッズ特捜隊'),
#  ('Q184534',
#   'Selimiye Mosqueq',
#   'mosque',
#   'جامع السليمية',
#   'Selimiye-Moschee',
#   'Mezquita de Selim',
#   'mosquée Selimiye',
#   'moschea Selimiye',
#   'セリミエ・モスク'),
#  ('Q659843',
#   'The Snake Pit',
#   'film',
#   'بيت الأفعى',
#   'Die Schlangengrube',
#   'Nido de víboras',
#   'La Fosse aux serpents',
#   'La fossa dei serpenti',
#   '蛇の穴'),
#  ('Q1974813',
#   'Zoological Museum of Moscow University',
#   'zoological museum',
#   '',
#   'Zoologisches Museum der Staatlichen Universität Moskau',
#   'Museo Zoológico de la Universidad de Moscú',
#   'musée zoologique de Moscou',
#   '',
#   ''),
#  ('Q653564',
#   'Ong Bak 2',
#   'film',
#   '',
#   'Ong-bak 2',
#   'Ong-Bak 2',
#   'Ong-bak 2 : La Naissance du dragon',
#   'Ong-Bak 2 - La nascita del dragone',
#   'マッハ!弐'),
#  ('Q1213800',
#   'The Cats of Ulthar',
#   'literary work',
#   'قطط أولثار',
#   'Die Katzen von Ulthar',
#   'Los gatos de Ulthar',
#   'Les Chats d’Ulthar',
#   'I gatti di Ulthar',
#   'ウルタール'),
#  ('Q1218663',
#   'The Indiscreet Jewels',
#   'written work',
#   'الحلي الظاهرة',
#   'Die indiskreten Kleinode',
#   '',
#   'Les Bijoux indiscrets',
#   'I gioielli indiscreti',
#   '不謹慎な宝石'),
#  ('Q1406280',
#   'Father and Son',
#   'film',
#   '',
#   'Vater und Sohn',
#   'Padre e hijo',
#   'Père, fils',
#   'Padre e figlio',
#   'ファザー、サン'),
#  ('Q887537',
#   'Presidential Seal of Turkey',
#   'national seal',
#   'الختم الرئاسي لتركيا',
#   'Standarte des türkischen Präsidenten',
#   '',
#   'Sceau présidentiel turc',
#   'Sigillo presidenziale turco',
#   ''),
#  ('Q688842',
#   'Frederick of Luxembourg',
#   'human',
#   'فريدريك من لوكسمبورغ',
#   'Friedrich',
#   'Federico de Luxemburgo',
#   'Frédéric de Luxembourg',
#   'Federico di Lussemburgo',
#   'フリードリヒ (モーゼルガウ伯)'),
#  ('Q1660217',
#   'Piano Trio No. 2',
#   'musical work/composition',
#   '',
#   'Klaviertrio Nr. 2',
#   'Trío para piano n.º 2',
#   'Trio pour piano et cordes nº 2 de Schubert',
#   'Trio per pianoforte n.2 (Schubert)',
#   'ピアノ三重奏曲第2番'),
#  ('Q1256501',
#   'Jameh Mosque of Isfahan',
#   'mosque',
#   'مسجد الجامع أصفهان',
#   'Freitagsmoschee von Isfahan',
#   'Gran Mezquita de Isfahán',
#   "Grande mosquée d'Ispahan",
#   'moschea del Venerdì di Isfahan',
#   'エスファハーンのジャーメ・モスク'),
#  ('Q2523375',
#   'Mimesis: The Representation of Reality in Western Literature',
#   'literary work',
#   '',
#   'Mimesis. Dargestellte Wirklichkeit in der abendländischen Literatur',
#   '',
#   'Mimésis',
#   'Mimesis. Il realismo nella letteratura occidentale',
#   'ミメーシス'),
#  ('Q3053656',
#   'In the Cart',
#   'literary work',
#   'مجلة الرسالة/العدد 623/القصص',
#   'Auf dem Wagen',
#   '',
#   'En tombereau',
#   '',
#   ''),
#  ('Q1995725',
#   'The Grand Chessboard',
#   'written work',
#   'رقعة الشطرنج الكبرى',
#   'Die einzige Weltmacht: Amerikas Strategie der Vorherrschaft',
#   '',
#   'Le Grand Échiquier',
#   '',
#   ''),
#  ('Q209705',
#   'Roskilde Cathedral',
#   'Lutheran cathedral',
#   '',
#   'Dom zu Roskilde',
#   'Catedral de Roskilde',
#   'cathédrale de Roskilde',
#   'cattedrale di Roskilde',
#   'ロスキレ大聖堂'),
#  ('Q614989',
#   'Dirty Dingus Magee',
#   'film',
#   '',
#   'Der „schärfste“ aller Banditen',
#   'Duelo de pillos',
#   'Un Beau Salaud',
#   'Dingus, quello sporco individuo',
#   '大悪党 ジンギス・マギー'),
#  ('Q181033',
#   'Emperor William Monument',
#   'Kaiser William monuments',
#   '',
#   'Kaiser-Wilhelm-Denkmal an der Porta Westfalica',
#   'Monumento al emperador Guillermo (Porta Westfalica)',
#   '',
#   "Monumento all'imperatore Guglielmo I",
#   'ヴィルヘルム皇帝記念碑 (ポルタ・ヴェストファーリカ)'),
#  ('Q11624398',
#   'Michihiko Fujiei',
#   'human',
#   '',
#   '',
#   'Michihiko Tōei',
#   '',
#   '',
#   '藤栄道彦'),
#  ('Q4015908',
#   'Treccani Vocabulary',
#   'written work',
#   'مفردات تريكاني',
#   '',
#   '',
#   'Vocabolario Treccani',
#   'Vocabolario Treccani',
#   'トレッカーニ語彙集'),
#  ('Q21539874',
#   "Dolly Parton's Coat of Many Colors",
#   'television film',
#   '',
#   '',
#   'Dolly Parton: Historia de una vida',
#   '',
#   '',
#   ''),
#  ('Q762704',
#   'The Guilty Mother',
#   'literary work',
#   '',
#   'La mère coupable',
#   'La madre culpable',
#   'La Mère coupable',
#   'La madre colpevole',
#   '罪ある母'),
#  ('Q7775573',
#   'The Woman with the Whip',
#   'book',
#   '',
#   '',
#   'La mujer con el látigo',
#   '',
#   '',
#   'ムチを持った女'),
#  ('Q230772',
#   'Piano Concerto No. 4',
#   'musical work/composition',
#   '',
#   '4. Klavierkonzert',
#   'Concierto para piano n.º 4',
#   'Concerto pour piano nº 4 de Beethoven',
#   'Concerto per pianoforte e orchestra n. 4',
#   'ピアノ協奏曲第4番 (ベートーヴェン)'),
#  ('Q385428',
#   'Altenburg Abbey',
#   'benedictine abbey',
#   '',
#   'Benediktinerkloster Altenburg, Österreich',
#   'abadía de Altenburg',
#   "abbaye d'Altenburg",
#   'abbazia di Altenburg',
#   'アルテンブルク修道院'),
#  ('Q166711',
#   'Elephant Walk',
#   'film',
#   '',
#   'Elefantenpfad',
#   'La senda de los elefantes',
#   'La Piste des éléphants',
#   'La pista degli elefanti',
#   '巨象の道'),
#  ('Q878124',
#   'Summer in Berlin',
#   'film',
#   'الصيف في برلين',
#   'Sommer vorm Balkon',
#   'Verano en Berlín',
#   'Un été à Berlin',
#   "Un'estate sul balcone",
#   ''),
#  ('Q1051458',
#   'Church of the Intercession on the Nerl',
#   'Eastern Orthodox church building',
#   'كنيسة الشفاعة على نهر النيل',
#   'Mariä-Schutz-und-Fürbitte-Kirche an der Nerl',
#   'iglesia de la Intercesión del río Nerl',
#   "église de l'Intercession de la Nerl",
#   "chiesa dell'Intercessione sul Nerl'",
#   '生神女庇護聖堂'),
#  ('Q104622663',
#   "The Surgeon's Cut",
#   'television series',
#   '',
#   'Der chirurgische Schnitt',
#   'Cirujanos innovadores',
#   '',
#   '',
#   ''),
#  ('Q5503354',
#   'Friar Laurence',
#   'theatrical character',
#   '',
#   'Friar Laurence',
#   'Fray Lorenzo',
#   '',
#   'Frate Lorenzo',
#   ''),
#  ('Q2045835',
#   'Yazidi Book of Revelation',
#   'book',
#   'كتاب الجلوة',
#   '',
#   'Kitêba Jilwe',
#   'Kitêba Cilwe',
#   '',
#   'キテバ・ジルウェ'),
#  ('Q2911055',
#   'The Vault',
#   'television series',
#   '',
#   '',
#   '',
#   'Le Coffre',
#   '',
#   'ザ・ボールト'),
#  ('Q965042',
#   'Armação Ilimitada',
#   'television series',
#   '',
#   'Das Chaotensyndikat',
#   '',
#   'Triangle en bermuda',
#   'Società a irresponsabilità illimitata',
#   ''),
#  ('Q2531250',
#   'The Man Who Fell to Earth',
#   'literary work',
#   '',
#   'Der Mann, der vom Himmel fiel',
#   '',
#   "L'Homme tombé du ciel",
#   "L'uomo che cadde sulla Terra",
#   '地球に落ちて来た男'),
#  ('Q544641',
#   'Mikhail Boyarsky',
#   'human',
#   '',
#   'Michail Sergejewitsch Bojarski',
#   'Mijaíl Boyarsky',
#   'Mikhaïl Boyarski',
#   'Michail Sergeevič Bojarskij',
#   'ミハイル・ボヤルスキー'),
#  ('Q100573244',
#   'The Big Hit',
#   'film',
#   '',
#   'Ein Triumph',
#   'El triunfo',
#   'Un triomphe',
#   'Un triomphe',
#   'アプローズ、アプローズ! 囚人たちの大舞台'),
#  ('Q1215903',
#   'The Incredible Hulk Returns',
#   'television film',
#   '',
#   'Die Rückkehr des unheimlichen Hulk',
#   'El increíble Hulk regresa',
#   "Le Retour de l'incroyable Hulk",
#   "La rivincita dell'incredibile Hulk",
#   ''),
#  ('Q3222389',
#   'The Mansion',
#   'literary work',
#   'القصر (رواية)',
#   'Das Haus',
#   'La mansión (novela de William Faulkner)',
#   'Le Domaine',
#   '',
#   '館 (フォークナー)'),
#  ('Q17596101',
#   'monkey selfie copyright dispute',
#   'photograph series',
#   'سيلفي القرد',
#   'Affen-Selfie',
#   'Wikipedia envuelta en un batalla legal de copyright por varias fotos autorretrato de un macaco',
#   'selfie par une macaque nègre femelle',
#   'Autoscatto del macaco',
#   'サルの自撮り'),
#  ('Q2079627',
#   'Holiday Affair',
#   'film',
#   '',
#   'Die Urlaubs-Affaire',
#   '',
#   'Mariage compliqué',
#   'Tu partirai con me',
#   'ママの青春'),
#  ('Q999862',
#   'Memorial to the Murdered Members of the Reichstag',
#   'memorial',
#   '',
#   'Denkmal zur Erinnerung an 96 von den Nationalsozialisten ermordete Reichstagsabgeordnete',
#   '',
#   'mémorial en souvenir des 96 membres du Reichstag assassinés par les nazis',
#   '',
#   ''),
#  ('Q2278469',
#   'Dead of Winter',
#   'film',
#   '',
#   'Tod im Winter',
#   'Muerte en el invierno',
#   'Froid comme la mort',
#   'Omicidio allo specchio',
#   '冬の嵐'),
#  ('Q391172',
#   'Secrets & Lies',
#   'film',
#   'أسرار وأكاذيب',
#   'Lügen und Geheimnisse',
#   'Secretos y mentiras',
#   'Secrets et mensonges',
#   'Segreti e bugie',
#   '秘密と嘘'),
#  ('Q240317',
#   'Princess Margarita of Greece and Denmark',
#   'human',
#   'مارغريتا أميرة اليونان والدنمارك',
#   'Margarita von Griechenland',
#   'Margarita de Grecia',
#   'Marguerite de Grèce',
#   'Margherita di Grecia',
#   'マルガリタ・ティス・エラザス'),
#  ('Q1764229',
#   'Battle of the Hornburg',
#   'fictional battle',
#   '',
#   'Schlacht um die Hornburg',
#   'Batalla del Abismo de Helm',
#   'Bataille de Fort-le-Cor',
#   'Battaglia del Fosso di Helm',
#   '角笛城の合戦'),
#  ('Q19724891',
#   'Asterix and the Missing Scroll',
#   'comic book album',
#   '',
#   'Der Papyrus des Cäsar',
#   'El papiro del César',
#   'Le Papyrus de César',
#   'Asterix e il papiro di Cesare',
#   ''),
#  ('Q1053061',
#   'cello scrotum',
#   'fictional medical condition',
#   '',
#   'Cello-Hoden',
#   'Escroto de violonchelo',
#   'scrotum du violoncelliste',
#   '',
#   ''),
#  ('Q357328',
#   'Saint Joan of the Stockyards',
#   'literary work',
#   '',
#   'Die heilige Johanna der Schlachthöfe',
#   '',
#   'Sainte Jeanne des Abattoirs',
#   'Santa Giovanna dei Macelli',
#   '屠殺場の聖ヨハンナ'),
#  ('Q114204558',
#   'Aleksey Nagin',
#   'human',
#   '',
#   '',
#   'Alekséi Naguin',
#   'Alexeï Naguine',
#   '',
#   ''),
#  ('Q7737383',
#   'The Gospel of Sri Ramakrishna',
#   'literary work',
#   '',
#   'Das Evangelium von Sri Ramakrishna',
#   'El Evangelio de Sri Ramakrishna',
#   "L'Évangile de Sri Ramakrishna",
#   '',
#   'ラーマクリシュナの福音'),
#  ('Q2468448',
#   'Four Quartets',
#   'written work',
#   'الرباعيات الأربع',
#   '',
#   'Cuatro cuartetos',
#   'Quatre Quatuors',
#   'Quattro quartetti',
#   '四つの四重奏曲'),
#  ('Q224417',
#   'Symphony No. 31',
#   'musical work/composition',
#   '',
#   '31. Sinfonie',
#   'Sinfonía n.º 31',
#   'Symphonie nº 31',
#   'Sinfonia n. 31',
#   '交響曲第31番 (モーツァルト)'),
#  ('Q1192719',
#   'The Bear',
#   'dramatic work',
#   '',
#   'Der Bär',
#   '',
#   "L'Ours",
#   "L'orso",
#   '熊'),
#  ('Q218295',
#   'President of Russia',
#   'state position of the Russian Federation',
#   'رئيس روسيا',
#   'Präsident Russlands',
#   'Presidente de la Federación',
#   'président de la fédération de Russie',
#   'presidente della Federazione Russa',
#   'ロシア連邦大統領'),
#  ('Q252633',
#   "Devil's Sea",
#   'geographic region',
#   'بحر الشيطان',
#   'Teufelsmeer',
#   'Mar del Diablo',
#   'Mer du Diable',
#   'Triangolo del Drago',
#   'ドラゴントライアングル'),
#  ('Q310549',
#   'Mass in B minor',
#   'musical work/composition',
#   '',
#   'h-Moll-Messe',
#   'Misa en si menor',
#   'Messe en si mineur',
#   'Messa in Si minore',
#   'ミサ曲 ロ短調'),
#  ('Q684239',
#   'Armenian Cathedral of Lviv',
#   'cathedral',
#   '',
#   'Armenische Kathedrale',
#   '',
#   'cathédrale arménienne de Lviv',
#   'Cattedrale armena',
#   'アルメニア教会'),
#  ('Q65695',
#   'Alexander Karl, Duke of Anhalt-Bernburg',
#   'human',
#   '',
#   'Alexander Carl',
#   'Alejandro Carlos de Anhalt-Bernburg',
#   "Alexandre-Charles d'Anhalt-Bernbourg",
#   'Alessandro Carlo di Anhalt-Bernburg',
#   'アレクサンダー・カール'),
#  ('Q116025248',
#   'The Lying Life of Adults',
#   'television series',
#   '',
#   'Das lügenhafte Leben der Erwachsenen',
#   'La vida mentirosa de los adultos',
#   'La Vie mensongère des adultes',
#   'La vita bugiarda degli adulti',
#   ''),
#  ('Q456945',
#   'Jason of Pherae',
#   'human',
#   '',
#   'Jason von Pherai',
#   'Jasón de Feres',
#   'Jason de Phères',
#   'Giasone di Fere',
#   'フェライのイアソン'),
#  ('Q1786452',
#   "Merlin's Apprentice",
#   'television film',
#   '',
#   'Merlin 2 – Der letzte Zauberer',
#   'El aprendiz de Merlín',
#   "L'Apprenti de Merlin",
#   "Merlino e l'apprendista stregone",
#   'エクスカリバーII 伝説の聖杯'),
#  ('Q7409412',
#   'Sami music',
#   'music by ethnic group',
#   '',
#   'Samische Musik',
#   'música saami',
#   '',
#   '',
#   ''),
#  ('Q651460',
#   'Guarding Tess',
#   'film',
#   'جاردينج تس',
#   'Tess und ihr Bodyguard',
#   'Tess y su guardaespaldas',
#   'Un ange gardien pour Tess',
#   'Cara, insopportabile Tess',
#   '不機嫌な赤いバラ'),
#  ('Q12695700',
#   'Eon duo',
#   'group of fictional characters',
#   '',
#   'Äon-Duo',
#   'dúo eón',
#   'Duo éon',
#   'Duo Eone',
#   ''),
#  ('Q1094894',
#   'Beautiful But Dangerous',
#   'film',
#   'جميلة لكن خطرة',
#   'Die schönste Frau der Welt',
#   'La mujer más guapa del mundo',
#   'La Belle des belles',
#   'La donna più bella del mondo',
#   ''),
#  ('Q4026',
#   'Ramesses X',
#   'human',
#   'رمسيس العاشر',
#   'Ramses X.',
#   'Ramsés X',
#   'Ramsès X',
#   'Ramses X',
#   'ラムセス10世'),
#  ('Q913426',
#   'The Irony of Fate',
#   'film',
#   'سخرية القدر',
#   'Ironie des Schicksals',
#   'La ironía del destino, o goce de su baño',
#   "L'Ironie du sort",
#   "Ironija sud'by, ili S lëgkim parom!",
#   '運命の皮肉、あるいはいい湯を'),
#  ('Q688979',
#   'The Workers of Vienna',
#   'musical work/composition',
#   '',
#   'Die Arbeiter von Wien',
#   'Los trabajadores de Viena',
#   'Vi bygger landet',
#   '',
#   'ウィーンの労働者'),
#  ('Q160341',
#   'Edward IV of England',
#   'human',
#   'إدوارد الرابع ملك إنجلترا',
#   'Eduard IV.',
#   'Eduardo IV de Inglaterra',
#   'Édouard IV',
#   "Edoardo IV d'Inghilterra",
#   'エドワード4世'),
#  ('Q1242146',
#   'Donskoy Monastery',
#   'Eastern Orthodox monastery',
#   '',
#   'Donskoi-Kloster',
#   'Monasterio Donskói',
#   'monastère de Donskoï',
#   'monastero Donskoj',
#   'ドンスコイ修道院'),
#  ('Q65926496',
#   'The Institute',
#   'literary work',
#   'المؤسسة (رواية)',
#   'Das Institut',
#   'El instituto',
#   "L'Institut",
#   "L'istituto",
#   ''),
#  ('Q2033042',
#   'The Snow Maiden',
#   'animated film',
#   '',
#   '',
#   'La doncella de nieve',
#   'La Fille des neiges',
#   '',
#   ''),
#  ('Q478209',
#   'Double Indemnity',
#   'film',
#   'تعويض مزدوج',
#   'Frau ohne Gewissen',
#   'Perdición',
#   'Assurance sur la mort',
#   'La fiamma del peccato',
#   '深夜の告白'),
#  ('Q28129997',
#   'Iron Spider',
#   'fictional powered exoskeleton',
#   '',
#   '',
#   'Araña de Hierro',
#   '',
#   '',
#   'アイアン・スパイダー'),
#  ('Q2739222',
#   'House Lannister',
#   'fictional noble family',
#   'آل لانستر',
#   'Haus Lannister',
#   'Casa Lannister',
#   'Maison Lannister',
#   'Casa Lannister',
#   ''),
#  ('Q4169287',
#   'butternut squash',
#   'cultivar',
#   'القرع العسلي',
#   'Butternutkürbis',
#   '',
#   'doubeurre',
#   'zucca butternut',
#   'バターナット・スクウォッシュ'),
#  ('Q704448',
#   'Go! Go! Itsutsugo Land',
#   'anime television series',
#   '',
#   '',
#   "Let's Go Quintuplets",
#   '',
#   'Cinque gemelli diversi',
#   'ゴーゴー五つ子ら・ん・ど'),
#  ('Q17047799',
#   'The Queen of Miami',
#   'television series',
#   'أصحاب الجنة',
#   '',
#   'Dueños del paraíso',
#   'Dueños del paraíso',
#   '',
#   ''),
#  ('Q7913042',
#   'Vampiyan Kids',
#   'anime television series',
#   '',
#   '',
#   '',
#   '',
#   'I Vampiriani - Vampiri vegetariani',
#   'バンパイヤン・キッズ'),
#  ('Q1308641',
#   'The Lonely Shepherd',
#   'musical work/composition',
#   'الراعي الوحيد',
#   'Einsamer Hirte',
#   'Einsamer Hirte',
#   'Einsamer Hirte',
#   'Einsamer Hirte',
#   'ロマーナの祈り'),
#  ('Q943755',
#   "JoJo's Circus",
#   'television series',
#   'سيرك جوجو',
#   'Jojos Zirkus',
#   'El circo de Jojo',
#   'Jojo Circus',
#   'Il circo di Jojo',
#   'ジョジョ・サーカス'),
#  ('Q3238123',
#   'winged unicorn',
#   'fictional species of animal',
#   '',
#   'Geflügeltes Einhorn',
#   'unicornio alado',
#   'licorne ailée',
#   'unicorno alato',
#   '有翼のユニコーン'),
#  ('Q1806888',
#   'Riyāḍ al-ṣāliḥīn',
#   'literary work',
#   'رياض الصالحين',
#   'Riyāḍ aṣ-ṣāliḥīn',
#   'Riyad al-salihin',
#   'Les Jardins des vertueux',
#   '',
#   '公正の庭'),
#  ('Q381854',
#   'Casimir Pulaski',
#   'human',
#   'كازيمير بولاسكي',
#   'Kazimierz Pułaski',
#   'Kazimierz Pułaski',
#   'Casimir Pulaski',
#   'Kazimierz Pułaski',
#   'カジミエシュ・プワスキ'),
#  ('Q3953301',
#   '1st & Ten',
#   'television series',
#   '',
#   'Touchdown',
#   '',
#   '',
#   'Scuola di football',
#   ''),
#  ...}

# %%
conn = sqlite3.connect('../database/entities.db')
cursor = conn.cursor()

cursor.execute('PRAGMA table_info(entity_translation);')
cursor.fetchall()
conn.close()

# %%
conn = sqlite3.connect('../database/ent.db')
cursor = conn.cursor()
cursor.execute('''CREATE TABLE entity_translation(
                    wiki_id PRIMARY KEY,
                    name NOT NULL,
                    instance_of,
                    ar,
                    de,
                    es,
                    fr, 
                    it,
                    ja 
               )''')

# %%
for item in all:
    try:
        cursor.execute("""INSERT INTO entity_translation (wiki_id, name, instance_of, ar, de, es, fr, it, ja) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
        """, item)
    except sqlite3.IntegrityError:
        print(item, "In db already")

conn.commit()

# %%
cursor.execute('SELECT * FROM entity_translation')
cursor.fetchall()
# Out:
# [('Q369547',
#   'Sázava Monastery',
#   'monastery',
#   '',
#   'Kloster Sázava',
#   'Monasterio de Sázava',
#   'monastère de Sázava',
#   'Monastero di Sázava',
#   ''),
#  ('Q779815',
#   'animation director',
#   'filmmaking occupation',
#   'مخرج رسوم متحركة',
#   'Regisseur für Animation',
#   'director de animación',
#   'chef-animateur',
#   "direttore dell'animazione",
#   '作画監督'),
#  ('Q863438',
#   'The Valley of Fear',
#   'literary work',
#   'وادي الخوف',
#   'Das Tal der Angst',
#   'El valle del terror',
#   'La Vallée de la peur',
#   'La valle della paura',
#   '恐怖の谷'),
#  ('Q853935',
#   'Kocatepe Mosque',
#   'mosque',
#   'جامع خوجه تبه',
#   'Kocatepe-Moschee',
#   'Mezquita Kocatepe',
#   'mosquée Kocatepe',
#   '',
#   'コジャテペ・モスク'),
#  ('Q190135',
#   'The Little Mermaid',
#   'animated film',
#   'حورية البحر',
#   'Arielle, die Meerjungfrau',
#   'La sirenita',
#   'La Petite Sirène',
#   'La sirenetta',
#   'リトル・マーメイド'),
#  ('Q183259',
#   'Super Nintendo Entertainment System',
#   'electronic device model',
#   'سوبر نينتندو إنترتينمنت سيستم',
#   'Super Nintendo Entertainment System',
#   'Super Nintendo Entertainment System',
#   'Super Nintendo Entertainment System',
#   'Super Nintendo Entertainment System',
#   'スーパーファミコン'),
#  ('Q506505',
#   'The Comedy of Errors',
#   'dramatic work',
#   'كوميديا الأخطاء',
#   'Die Komödie der Irrungen',
#   'La comedia de las equivocaciones',
#   'La Comédie des erreurs',
#   'La commedia degli errori',
#   '間違いの喜劇'),
#  ('Q13923',
#   'The Grim Adventures of Billy & Mandy',
#   'animated television series',
#   'مغامرات بيلي وماندي',
#   'Die gruseligen Abenteuer von Billy und Mandy',
#   'The Grim Adventures of Billy & Mandy',
#   "Billy et Mandy, aventuriers de l'au-delà",
#   'Le tenebrose avventure di Billy e Mandy',
#   'ビリー&マンディ'),
#  ('Q974775',
#   'Olympiodorus the Younger',
#   'human',
#   'أولمبردس الصغير',
#   'Olympiodoros der Jüngere',
#   'Olimpiodoro el Joven',
#   'Olympiodore le Jeune',
#   'Olimpiodoro il Giovane',
#   'オリンピオドロス'),
#  ('Q162062',
#   'Pentateuch',
#   'religious text',
#   '',
#   'Pentateuch',
#   'Pentateuco',
#   'Pentateuque',
#   'Pentateuco',
#   'モーセ五書'),
#  ('Q80692',
#   'Richeza of Poland, Queen of Castile',
#   'human',
#   'ريكولدا من بولندا',
#   'Richeza von Everstein',
#   'Riquilda de Polonia',
#   'Richezza de Pologne',
#   'Richenza di Polonia',
#   'リクサ・シロンスカ'),
#  ('Q1352126',
#   'Melitius of Lycopolis',
#   'human',
#   '',
#   'Meletios von Lykopolis',
#   'Melicio de Licòpolis',
#   'Mélitios de Lycopolis',
#   'Melezio di Licopoli',
#   'リコポリスのメレティオス'),
#  ('Q49575',
#   'Dizzy Gillespie',
#   'human',
#   'ديزي غيليسبي',
#   'Dizzy Gillespie',
#   'Dizzy Gillespie',
#   'Dizzy Gillespie',
#   'Dizzy Gillespie',
#   'ディジー・ガレスピー'),
#  ('Q12204253',
#   'Al-Sayeda Nafeesah Mosque',
#   'mosque',
#   'جامع السيدة نفيسة',
#   'Saiyida-Nafisa-Moschee',
#   'Al-Sayyida Nafisa',
#   'Al-Sayyida Nafisa',
#   '',
#   ''),
#  ('Q28102177',
#   'My Knight and Me',
#   'television series',
#   '',
#   'Ritter Hoch 3',
#   'Mi Caballero y Yo',
#   'Mon chevalier et moi',
#   "L'apprendista cavaliere",
#   '私の騎士と私'),
#  ('Q193066',
#   "Breakfast at Tiffany's",
#   'film',
#   'الإفطار عند تيفاني',
#   'Frühstück bei Tiffany',
#   "Breakfast at Tiffany's",
#   'Diamants sur canapé',
#   'Colazione da Tiffany',
#   'ティファニーで朝食を'),
#  ('Q1020994',
#   'citizen',
#   'role',
#   'مواطن',
#   'Bürger',
#   'ciudadano',
#   'citoyen',
#   'cittadino',
#   '公民'),
#  ('Q51403',
#   'Man in Black',
#   'fictional human',
#   '',
#   'Mann in Schwarz',
#   'Hombre de Negro',
#   "L'homme en noir",
#   'Uomo in nero',
#   '黒服の男'),
#  ('Q271815',
#   'Eleanor, Countess of Vermandois',
#   'human',
#   '',
#   'Eleonore von Vermandois',
#   'Eleonor de Vermandois',
#   'Éléonore de Vermandois',
#   'Eleonora di Vermandois',
#   'エレオノール (ヴェルマンドワ女伯)'),
#  ('Q11621',
#   'E.T. the Extra-Terrestrial',
#   'film',
#   'إي تي',
#   'E.T. – Der Außerirdische',
#   'E.T., el extraterrestre',
#   "E.T., l'extra-terrestre",
#   "E.T. l'extra-terrestre",
#   'E.T.'),
#  ('Q93535',
#   'Marie Christine, Princess Michael of Kent',
#   'human',
#   'مايكل أميرة كينت',
#   'Marie Christine von Reibnitz',
#   'María Cristina de Reibnitz',
#   'Marie-Christine von Reibnitz',
#   'Marie Christine von Reibnitz',
#   'マリー＝クリスティーヌ'),
#  ('Q176609',
#   'Arctic Circle',
#   'polar circle',
#   'الدائرة القطبية الشمالية',
#   'nördlicher Polarkreis',
#   'círculo polar ártico',
#   'Cercle Arctique',
#   'Circolo polare artico',
#   '北極圏'),
#  ('Q127552',
#   'Pixar',
#   'animation studio',
#   'بيكسار',
#   'Pixar',
#   'Pixar',
#   'Pixar Animation Studios',
#   'Pixar Animation Studios',
#   'ピクサー・アニメーション・スタジオ'),
#  ('Q2570624',
#   'Radisson Royal Hotel',
#   'hotel',
#   'فندق أوكرانيا',
#   '',
#   'Hotel Ucrania',
#   'hôtel Ukraine',
#   'Hotel Ucraina',
#   'ホテル・ウクライナ'),
#  ('Q6661985',
#   'data processing',
#   'information processing',
#   'معالجة البيانات',
#   'Datenverarbeitung',
#   'procesamiento de datos',
#   'traitement de données',
#   'elaborazione dati',
#   'データ処理'),
#  ('Q3203583',
#   'Man a Machine',
#   'literary work',
#   '',
#   '',
#   'El hombre máquina',
#   "L'Homme Machine",
#   "L'Homme Machine",
#   '人間機械論'),
#  ('Q14906755',
#   'Cloak of Invisibility',
#   'magical object in Harry Potter',
#   '',
#   'Tarnumhang',
#   'Capa de Invisibilidad',
#   "Cape d'invisibilité",
#   "Mantello dell'invisibilità",
#   ''),
#  ('Q1492',
#   'Barcelona',
#   'municipality of Catalonia',
#   'برشلونة',
#   'Barcelona',
#   'Barcelona',
#   'Barcelone',
#   'Barcellona',
#   'バルセロナ'),
#  ('Q298310',
#   'David Bisbal',
#   'human',
#   'دافيد بيسبال',
#   'David Bisbal',
#   'David Bisbal',
#   'David Bisbal',
#   'David Bisbal',
#   'ダビッド・ビスバル'),
#  ('Q844473',
#   'Dark Eyes',
#   'musical work/composition',
#   'العيون السوداء',
#   'Schwarze Augen',
#   'Ojos Negros',
#   'Les Yeux noirs',
#   'Occhi neri',
#   '黒い瞳'),
#  ('Q83468',
#   'Judas Priest',
#   'heavy metal band',
#   'جوداس بريست',
#   'Judas Priest',
#   'Judas Priest',
#   'Judas Priest',
#   'Judas Priest',
#   'ジューダス・プリースト'),
#  ('Q200686',
#   'French Fifth Republic',
#   'republic regime in France',
#   'الجمهورية الفرنسية الخامسة',
#   'Fünfte Französische Republik',
#   'Quinta República Francesa',
#   'Cinquième République',
#   'Quinta Repubblica francese',
#   'フランス第五共和政'),
#  ('Q2599',
#   'Paul McCartney',
#   'human',
#   'بول مكارتني',
#   'Paul McCartney',
#   'Paul McCartney',
#   'Paul McCartney',
#   'Paul McCartney',
#   'ポール・マッカートニー'),
#  ('Q228624',
#   'Suzanne Collins',
#   'human',
#   'سوزان كولنز',
#   'Suzanne Collins',
#   'Suzanne Collins',
#   'Suzanne Collins',
#   'Suzanne Collins',
#   'スーザン・コリンズ'),
#  ('Q1198412',
#   'Too Late for Tears',
#   'film',
#   '',
#   'Der blonde Tiger',
#   'Demasiado tarde para lágrimas',
#   'La Tigresse',
#   'È tardi per piangere',
#   'トゥー・レイト・フォー・ティアーズ'),
#  ('Q1064807',
#   'Super Bowl XXIV',
#   'Super Bowl',
#   'سوبر بول XXIV',
#   'Super Bowl XXIV',
#   'Super Bowl XXIV',
#   'Super Bowl XXIV',
#   'Super Bowl XXIV',
#   '第24回スーパーボウル'),
#  ('Q1076874',
#   'fried rice',
#   'dish',
#   'الأرز المقلي',
#   'gebratener Reis',
#   'arroz frito',
#   'riz frit',
#   'riso fritto',
#   'チャーハン'),
#  ('Q2585559',
#   'The Kingkiller Chronicle',
#   'literary trilogy',
#   '',
#   'The Kingkiller Chronicle',
#   'Crónica del asesino de reyes',
#   'Chronique du tueur de roi',
#   "Le Cronache dell'Assassino del Re",
#   'キングキラー・クロニクル'),
#  ('Q175565',
#   'String Quartet No. 13',
#   'musical work/composition',
#   '',
#   '13. Streichquartett',
#   'Cuarteto de cuerda n.º 13 Op. 130',
#   'Quatuor à cordes nº 13 de Beethoven',
#   'Quartetto n. 13',
#   '弦楽四重奏曲第13番 (ベートーヴェン)'),
#  ('Q1437026',
#   'Two Half Times in Hell',
#   'film',
#   '',
#   'Zwei Halbzeiten in der Hölle',
#   'Match en el infierno',
#   'Deux Mi-temps en enfer',
#   "Due tempi all'inferno",
#   '地獄のハーフタイム'),
#  ('Q571251',
#   'association football goal',
#   'product category',
#   'مرمى ملعب كرة قدم',
#   'Tor',
#   'portería',
#   'but',
#   'porta',
#   'サッカーのゴール'),
#  ('Q628443',
#   'The Steam House',
#   'literary work',
#   'بيت البخار',
#   'Das Dampfhaus',
#   'La casa de vapor',
#   'La Maison à vapeur',
#   'La casa a vapore',
#   '蒸気の家'),
#  ('Q1016744',
#   'Bornay Mosque',
#   'mosque',
#   'مسجد بورناي',
#   'Burnajewskaja-Moschee',
#   '',
#   '',
#   '',
#   ''),
#  ('Q941517',
#   'Imagination Movers',
#   'television series',
#   'محركو الخيال',
#   'Die Ideen-Meister',
#   'Los Imaginadores',
#   '',
#   '',
#   'あそぼう!イマジネーションムーバーズ'),
#  ('Q107351551',
#   'Sāmī ʻĀmirī',
#   'human',
#   'سامي عامري',
#   'Sami Ameri',
#   '',
#   'Sami Ameri',
#   '',
#   ''),
#  ('Q13979',
#   'Saturday Night Live',
#   'television series',
#   'ساترداي نايت لايف',
#   'Saturday Night Live',
#   'Saturday Night Live',
#   'Saturday Night Live',
#   'Saturday Night Live',
#   'サタデー・ナイト・ライブ'),
#  ('Q15615',
#   'Lil Wayne',
#   'human',
#   'ليل وين',
#   'Lil Wayne',
#   'Lil Wayne',
#   'Lil Wayne',
#   'Lil Wayne',
#   'リル・ウェイン'),
#  ('Q13695',
#   'Tenochtitlan',
#   'altepetl',
#   'تينوتشتيتلان',
#   'Tenochtitlan',
#   'México-Tenochtitlan',
#   'Mexico-Tenochtitlan',
#   'Tenochtitlán',
#   'テノチティトラン'),
#  ('Q47464862',
#   'The Heroic Quest of the Valiant Prince Ivandoe',
#   'animated television series',
#   'السعي البطولي للأمير الشجاع آيفاندو',
#   'Die heldenhafte Reise des tapferen Prinz Ivandoe',
#   'El valiente príncipe Ivandoe',
#   'La Quête héroïque du valeureux Prince Ivandoe',
#   'Il principe Ivandoe',
#   ''),
#  ('Q177220',
#   'singer',
#   'musical profession',
#   'مغني',
#   'Sänger',
#   'cantante',
#   'chanteur ou chanteuse',
#   'cantante',
#   '歌手'),
#  ('Q930887',
#   'Vegas Vacation',
#   'film',
#   'عطلة فيغاس',
#   'Die schrillen Vier in Las Vegas',
#   'Vacaciones en Las Vegas',
#   'Bonjour les vacances : Viva Las Vegas',
#   'Las Vegas - Una vacanza al casinò',
#   'ベガス・バケーション'),
#  ('Q2344561',
#   'Putra Mosque',
#   'mosque',
#   'مسجد بوترا',
#   'Putra-Moschee',
#   'Mezquita Putra',
#   'mosquée Putra',
#   '',
#   'プトラ・モスク'),
#  ('Q498384',
#   'Back from Eternity',
#   'film',
#   '',
#   'Zurück aus der Ewigkeit',
#   'Regreso de la eternidad',
#   'Les Échappés du néant',
#   "Ritorno dall'eternità",
#   '地獄の罠'),
#  ('Q738056',
#   'The Iron Mask',
#   'film',
#   'القناع الحديدي',
#   'Die eiserne Maske',
#   'La máscara de hierro',
#   'Le Masque de fer',
#   'La maschera di ferro',
#   '鉄仮面'),
#  ('Q5694782',
#   'Heaven and Hell',
#   'literary work',
#   '',
#   'Himmel und Hölle',
#   'De caelo et ejus mirabilibus et de inferno, ex auditis et visis',
#   '',
#   'Cielo e inferno',
#   ''),
#  ('Q4645817',
#   '92 in the Shade',
#   'film',
#   '',
#   '33 Grad im Schatten',
#   'Venganza anunciada',
#   "Trente-sept degrés à l'ombre",
#   "Novantadue gradi all'ombra",
#   ''),
#  ('Q5917807',
#   'How I Live Now',
#   'literary work',
#   '',
#   'So lebe ich jetzt',
#   '',
#   "Maintenant, c'est ma vie",
#   '',
#   ''),
#  ('Q1233716',
#   'Big Deal on Madonna Street',
#   'film',
#   '',
#   'Diebe haben’s schwer',
#   'Los desconocidos de siempre',
#   'Le Pigeon',
#   'I soliti ignoti',
#   'いつもの見知らぬ男たち'),
#  ('Q2562710',
#   'Waves of the Danube',
#   'musical work/composition',
#   '',
#   'Donauwellen',
#   'Olas del Danubio',
#   'Les Flots du Danube',
#   'Le onde del Danubio',
#   'ドナウ川のさざなみ'),
#  ('Q500538',
#   'High School Girls',
#   'manga series',
#   'هاي سكول غيرلز',
#   'Joshi Kōsei',
#   'Joshikōsei',
#   '',
#   '',
#   '女子高生'),
#  ('Q81329957',
#   'My Roomie Is a Dino',
#   'manga',
#   '',
#   '',
#   'Gal to Kyōryū',
#   '',
#   '',
#   'ギャルと恐竜'),
#  ('Q16165135',
#   'Pig Goat Banana Cricket',
#   'television series',
#   'بيغ غوت بانانا كريكيت',
#   'Schwein Ziege Banane Grille',
#   'Cerdo Cabra Banana Grillo',
#   'Cochon Chèvre Banane Criquet',
#   'Maiale Capra Banana Grillo',
#   ''),
#  ('Q216868',
#   'Chesapeake Bay',
#   'estuary',
#   'خليج تشيزبيك',
#   'Chesapeake Bay',
#   'bahía de Chesapeake',
#   'baie de Chesapeake',
#   'baia di Chesapeake',
#   'チェサピーク湾'),
#  ('Q478016',
#   'To the Lighthouse',
#   'literary work',
#   'إلى المنارة',
#   'Die Fahrt zum Leuchtturm',
#   'Al faro',
#   'La Promenade au phare',
#   'Gita al faro',
#   '灯台へ'),
#  ('Q7741197',
#   'The Hydrogen Sonata',
#   'literary work',
#   '',
#   'Die Wasserstoffsonate',
#   'La sonata del hidrógeno',
#   'La Sonate Hydrogène',
#   '',
#   '水素ソナタ'),
#  ('Q44555',
#   'Crazy Horse',
#   'human',
#   'الجواد الجامح',
#   'Crazy Horse',
#   'Caballo Loco',
#   'Crazy Horse',
#   'Cavallo Pazzo',
#   'クレイジー・ホース'),
#  ('Q1339305',
#   'Romford',
#   'town',
#   'رومفورد',
#   '',
#   'Romford',
#   'Romford',
#   'Romford',
#   'ロムフォード'),
#  ('Q1751487',
#   'Platov South-Russian State Polytechnic University',
#   'university',
#   'جامعة جنوب روسيا التقنية',
#   'Südrussische Staatliche Technische Universität',
#   'Universidad Técnica Estatal del Sur de Rusia',
#   "université technique d'État de Novotcherkassk",
#   '',
#   ''),
#  ('Q334051',
#   'Abbey of Monte Cassino',
#   'benedictine abbey',
#   '',
#   'Abtei Montecassino',
#   'abadía de Montecasino',
#   'abbaye du Mont-Cassin',
#   'abbazia di Montecassino',
#   'モンテ・カッシーノ修道院'),
#  ('Q131097',
#   'Epistle of James',
#   'religious text',
#   'رسالة يعقوب',
#   'Jakobus',
#   'Epístola de Santiago',
#   'Épître de Jacques',
#   'Lettera di Giacomo',
#   'ヤコブの手紙'),
#  ('Q7467',
#   'Priory Palace',
#   'palace',
#   '',
#   'Prioren Palast',
#   'Palacio del Priorato',
#   'palais du Prieuré',
#   'Palazzo del Priorato',
#   ''),
#  ('Q3213985',
#   'The Truth About the Harry Quebert Affair',
#   'literary work',
#   '',
#   'Die Wahrheit über den Fall Harry Quebert',
#   'La verdad sobre el caso Harry Quebert',
#   "La Vérité sur l'affaire Harry Quebert",
#   'La verità sul caso Harry Quebert',
#   ''),
#  ('Q4965928',
#   'Brick Lane Mosque',
#   'mosque',
#   'مسجد بريك لين',
#   'Brick-Lane-Moschee',
#   '',
#   '',
#   '',
#   ''),
#  ('Q517',
#   'Napoleon',
#   'human',
#   'نابليون بونابرت',
#   'Napoleon Bonaparte',
#   'Napoleón Bonaparte',
#   'Napoléon Ier',
#   'Napoleone Bonaparte',
#   'ナポレオン・ボナパルト'),
#  ('Q474',
#   'aqueduct',
#   'hydraulic structure',
#   'قناة مائية',
#   'Aquädukt',
#   'acueducto',
#   'aqueduc',
#   'acquedotto',
#   '用水路'),
#  ('Q1321004',
#   'You Will Meet a Tall Dark Stranger',
#   'film',
#   '',
#   'Ich sehe den Mann deiner Träume',
#   'Conocerás al hombre de tus sueños',
#   'Vous allez rencontrer un bel et sombre inconnu',
#   "Incontrerai l'uomo dei tuoi sogni",
#   '恋のロンドン狂騒曲'),
#  ('Q517453',
#   'Horus Bird',
#   'human',
#   'حورس با',
#   'Vogel',
#   'Horus Bird',
#   'Horus Oiseau',
#   'Ba',
#   ''),
#  ('Q1699208',
#   'Ras Cory',
#   'musical group',
#   '',
#   'Midnite',
#   'Midnite',
#   'Midnite',
#   'Midnite',
#   'ミッドナイト'),
#  ('Q2378785',
#   'Beatrice of Bohemia',
#   'human',
#   '',
#   'Beatrice von Böhmen',
#   'Beatriz de Bohemia',
#   'Béatrice de Bohême',
#   '',
#   'ベアトリクス・フォン・ベーメン'),
#  ('Q1211934',
#   'Hispanic',
#   'culture',
#   'هيسبانو',
#   'Hispanics',
#   'hispanos',
#   'hispanique',
#   'ispanica',
#   'ヒスパニック'),
#  ('Q212464',
#   'New Kids on the Block',
#   'musical group',
#   'نيو كيدز أون دا بلوك',
#   'New Kids on the Block',
#   'New Kids on the Block',
#   'New Kids on the Block',
#   'New Kids on the Block',
#   'ニュー・キッズ・オン・ザ・ブロック'),
#  ('Q242287',
#   'Joan of England',
#   'human',
#   '',
#   'Johanna von England',
#   'Juana de Inglaterra, reina de Escocia',
#   "Jeanne d'Angleterre",
#   'Giovanna Plantageneto',
#   'ジョーン・オブ・イングランド'),
#  ('Q2115452',
#   'Prelude in C-sharp minor',
#   'musical work/composition',
#   '',
#   'Prélude cis-Moll',
#   'Preludio en do sostenido menor (Rajmáninov)',
#   '',
#   'Preludio in Do diesis minore',
#   '前奏曲嬰ハ短調 (ラフマニノフ)'),
#  ('Q2388422',
#   'Kudrinskaya Square Building',
#   'revenue house',
#   '',
#   '',
#   'Edificio de la plaza Kudrinskaya',
#   "immeuble d'habitation de la place Koudrine",
#   'Edificio residenziale in piazza Kudrinskaja',
#   ''),
#  ('Q182865',
#   'War in Afghanistan',
#   'military campaign',
#   'حرب أفغانستان',
#   'Krieg in Afghanistan 2001–2021',
#   'guerra de Afganistán',
#   "guerre d'Afghanistan",
#   'guerra in Afghanistan',
#   'アフガニスタン紛争'),
#  ('Q180402',
#   'Yosemite National Park',
#   'National Park of the United States',
#   'متنزه يوسيميتي الوطني',
#   'Yosemite-Nationalpark',
#   'Parque nacional de Yosemite',
#   'parc national de Yosemite',
#   'parco nazionale di Yosemite',
#   'ヨセミテ国立公園'),
#  ('Q11872',
#   'The Steadfast Tin Soldier',
#   'literary work',
#   '',
#   'Der standhafte Zinnsoldat',
#   'El soldadito de plomo',
#   'Le Stoïque Soldat de plomb',
#   'Il soldatino di stagno',
#   'しっかり者のスズの兵隊'),
#  ('Q5043',
#   'Christianity',
#   'major religion',
#   'المسيحية',
#   'Christentum',
#   'cristianismo',
#   'christianisme',
#   'cristianesimo',
#   'キリスト教'),
#  ('Q1680069',
#   'Surviving Picasso',
#   'film',
#   '',
#   'Mein Mann Picasso',
#   'Sobrevivir a Picasso',
#   'Surviving Picasso',
#   'Surviving Picasso',
#   'サバイビング・ピカソ'),
#  ('Q1617364',
#   "Dr. Terror's House of Horrors",
#   'film',
#   '',
#   'Die Todeskarten des Dr. Schreck',
#   'Doctor Terror',
#   'Le Train des épouvantes',
#   'Le cinque chiavi del terrore',
#   'テラー博士の恐怖'),
#  ('Q12170857',
#   'Klim Churyumov',
#   'human',
#   'كليم تشوريوموف',
#   'Klym Tschurjumow',
#   'Klim Churyumov',
#   'Klym Tchourioumov',
#   'Klym Čurjumov',
#   'クリム・チュリュモフ'),
#  ('Q707502',
#   'The Rape of Nanking',
#   'written work',
#   'اغتصاب نانكينغ (كتاب)',
#   '',
#   '',
#   'Le viol de Nankin',
#   'Lo stupro di Nanchino',
#   'ザ・レイプ・オブ・南京'),
#  ('Q272076',
#   'Dean Koontz',
#   'human',
#   'دين كونتز',
#   'Dean Koontz',
#   'Dean Koontz',
#   'Dean Koontz',
#   'Dean Koontz',
#   'ディーン・R・クーンツ'),
#  ('Q2024169',
#   'Princess Désirée, Baroness Silfverschiöld',
#   'human',
#   '',
#   'Désirée Silfverschiöld',
#   'Désirée Bernadotte',
#   'Désirée de Suède',
#   'Desirée di Svezia',
#   ''),
#  ('Q12379',
#   'Mario',
#   'fictional human',
#   'ماريو',
#   'Mario',
#   'Mario',
#   'Mario',
#   'Mario',
#   'マリオ'),
#  ('Q12603',
#   'Pacific Northwest',
#   'geographic region',
#   'إقليم الشمال الغربي الهادئ',
#   'Pazifischer Nordwesten',
#   'Noroeste Pacífico',
#   'Nord-Ouest Pacifique',
#   'Pacifico nordoccidentale',
#   '太平洋岸北西部'),
#  ('Q724',
#   'Maine',
#   'U.S. state',
#   'مين',
#   'Maine',
#   'Maine',
#   'Maine',
#   'Maine',
#   'メイン州'),
#  ('Q2704285',
#   "Friday I'm in Love",
#   'single',
#   '',
#   "Friday I'm in Love",
#   "Friday I'm in Love",
#   "Friday I'm in Love",
#   "Friday I'm in Love",
#   ''),
#  ('Q2638238',
#   'Vyborg railway station',
#   'railway station',
#   '',
#   'Wyborg',
#   '',
#   'Vyborg',
#   '',
#   ''),
#  ('Q1093846',
#   'La Seine no Hoshi',
#   'anime television series',
#   '',
#   'Nadine – Stern der Seine',
#   '',
#   'La Tulipe noire',
#   'Il Tulipano Nero',
#   'ラ・セーヌの星'),
#  ('Q152095',
#   'bathtub',
#   'physical container',
#   'حوض استحمام',
#   'Badewanne',
#   'bañera',
#   'baignoire',
#   'vasca da bagno',
#   '浴槽'),
#  ('Q804208',
#   'Bajrakli Mosque',
#   'mosque',
#   'مسجد بجراكلي (بلغراد)',
#   'Bajrakli-Moschee (Belgrad)',
#   'Mezquita Bajrakli',
#   'mosquée Bajrakli de Belgrade',
#   '',
#   'バイラクリ・モスク'),
#  ('Q1306291',
#   'A Memory of Solferino',
#   'literary work',
#   '',
#   'Eine Erinnerung an Solferino',
#   'Un recuerdo de Solferino',
#   'Un souvenir de Solférino',
#   'Un Souvenir de Solférino',
#   'ソルフェリーノの思い出'),
#  ('Q2594210',
#   'Seal of Solomon',
#   'seal',
#   'خاتم سليمان',
#   '',
#   'Sello de Salomón (leyenda)',
#   'Sceau de Salomon',
#   '',
#   'ソロモンの指輪'),
#  ('Q2495862',
#   'congress',
#   'meeting',
#   'كونغرس',
#   'Kongress',
#   'congreso',
#   'congrès',
#   'congresso',
#   '代表大会'),
#  ('Q308966',
#   'San Francisco Giants',
#   'baseball team',
#   'سان فرانسيسكو جاينتس',
#   'San Francisco Giants',
#   'San Francisco Gigantes',
#   'Giants de San Francisco',
#   'San Francisco Giants',
#   'サンフランシスコ・ジャイアンツ'),
#  ('Q93332',
#   'Appalachian Mountains',
#   'mountain range',
#   'جبال الأبالاش',
#   'Appalachen',
#   'Apalaches',
#   'Appalaches',
#   'Appalachi',
#   'アパラチア山脈'),
#  ('Q7347',
#   'Great Lakes',
#   'group of interconnected lakes',
#   'البحيرات العظمى',
#   'Große Seen',
#   'Grandes Lagos',
#   'Grands Lacs',
#   'Grandi Laghi',
#   '五大湖'),
#  ('Q17071479',
#   'Who Fears Death',
#   'literary work',
#   'من يخاف الموت',
#   '',
#   '',
#   'Qui a peur de la mort ?',
#   '',
#   ''),
#  ('Q2180182',
#   'Conan the Warrior',
#   'collection of literary works',
#   '',
#   '',
#   'Conan the Warrior',
#   'Conan le guerrier',
#   'Conan il guerriero',
#   ''),
#  ('Q7860088',
#   'Tyler Moon',
#   'fictional human',
#   '',
#   '',
#   'Tony Discipline',
#   '',
#   '',
#   ''),
#  ('Q235539',
#   'Mount Whitney',
#   'mountain',
#   'جبل ويتني',
#   'Mount Whitney',
#   'Monte Whitney',
#   'mont Whitney',
#   'Monte Whitney',
#   'ホイットニー山'),
#  ('Q728404',
#   'The Pelican Brief',
#   'film',
#   'قضية البجع',
#   'Die Akte',
#   'El informe Pelícano',
#   "L'Affaire Pélican",
#   'Il rapporto Pelican',
#   'ペリカン文書'),
#  ('Q4189105',
#   'Memorial to Defenders of the Soviet Arctic during the Great Patriotic War',
#   'monumental sculpture',
#   'نصب أليوشا التذكاري',
#   'Aljoscha-Monument',
#   '',
#   "monument aux défenseurs de l'Arctique soviétique pendant la Grande Guerre patriotique",
#   "Monumento ai difensori dell'Artico sovietico durante la grande guerra patriottica",
#   'ソビエト極北防衛隊慰霊碑'),
#  ('Q93352',
#   'coast',
#   'place type',
#   'ساحل',
#   'Küste',
#   'costa',
#   'côte',
#   'costa',
#   '海岸'),
#  ('Q1637730',
#   'The Dark Tower III: The Waste Lands',
#   'literary work',
#   'برج الظلام 3: الأراضي اليباب (رواية)',
#   'Tot',
#   'Las tierras baldías',
#   'Terres perdues',
#   'Terre desolate',
#   ''),
#  ('Q1010828',
#   'Aremberg Castle',
#   'castle',
#   '',
#   'Burg Aremberg',
#   'castillo de Aremberg',
#   '',
#   '',
#   ''),
#  ('Q60063045',
#   'The Light in Your Eyes',
#   'television series',
#   'النور في عينيك',
#   'Radiant',
#   'Radiant (La luz en tus ojos)',
#   '',
#   'Nun-i busige',
#   '眩しくて'),
#  ('Q1002362',
#   'The Signal-Man',
#   'literary work',
#   'عامل الإشارة',
#   '',
#   'El guardavía',
#   '',
#   'Il segnalatore',
#   'The Signal-Man'),
#  ('Q1912490',
#   'Prince Max, Duke in Bavaria',
#   'human',
#   '',
#   'Prinz Max Emanuel, Herzog in Bayern',
#   'Max Emanuel de Baviera',
#   'Max Emmanuel von Wittelsbach',
#   'Max in Baviera',
#   'マックス・エマヌエル・イン・バイエルン'),
#  ('Q846224',
#   'fighting game',
#   'video game genre',
#   'لعبة قتال',
#   'Kampfspiel',
#   'videojuego de lucha',
#   'jeu vidéo de combat',
#   'picchiaduro',
#   '対戦格闘ゲーム'),
#  ('Q3772',
#   'Quentin Tarantino',
#   'human',
#   'كوينتن تارانتينو',
#   'Quentin Tarantino',
#   'Quentin Tarantino',
#   'Quentin Tarantino',
#   'Quentin Tarantino',
#   'クエンティン・タランティーノ'),
#  ('Q311441',
#   "Al-Rifa'i Mosque",
#   'mosque',
#   'مسجد الرفاعي',
#   "Ar-Rifa'i-Moschee",
#   "Mezquita de Al Rifa'i",
#   "mosquée Al-Rifa'i",
#   "moschea di al-Rifa'i",
#   'アッ＝リファーイー・モスク'),
#  ('Q51724',
#   'Jedi',
#   'fictional group of characters',
#   'جيدي',
#   'Jedi',
#   'Jedi',
#   'Jedi',
#   'Jedi',
#   'ジェダイ'),
#  ('Q3227112',
#   'The Promise',
#   'television series',
#   'الوعد',
#   'Gelobtes Land',
#   'La promesa',
#   'Le Serment',
#   '',
#   ''),
#  ('Q96377121',
#   'The Hunger Games: The Ballad of Songbirds and Snakes',
#   'prequel',
#   'مباريات الجوع: أغنية الطيور المغردة والثعابين',
#   'Die Tribute von Panem – The Ballad of Songbirds and Snakes',
#   'Los juegos del hambre: balada de pájaros cantores y serpientes',
#   "Hunger Games : La Ballade du serpent et de l'oiseau chanteur",
#   "Hunger Games - La ballata dell'usignolo e del serpente",
#   'ハンガー・ゲーム0'),
#  ('Q246546',
#   'Symphony No. 6',
#   'musical work/composition',
#   '',
#   '6. Sinfonie',
#   'Sinfonía n.º 6',
#   'Symphonie nº 6 de Sibelius',
#   'Sinfonia n. 6',
#   '交響曲第6番 (シベリウス)'),
#  ('Q963659',
#   'Dombey and Son',
#   'literary work',
#   'دومبي وابنه',
#   'Dombey und Sohn',
#   'Dombey e hijo',
#   'Dombey et Fils',
#   'Dombey e Figlio',
#   'ドンビー父子'),
#  ('Q27204',
#   'Live and Let Die',
#   'film',
#   'عش ودعهم يموتون',
#   'James Bond 007 – Leben und sterben lassen',
#   'Vive y deja morir',
#   'Vivre et laisser mourir',
#   'Agente 007 - Vivi e lascia morire',
#   '007 死ぬのは奴らだ'),
#  ('Q727016',
#   'Boys Town',
#   'film',
#   'مدينة الصبيان',
#   'Teufelskerle',
#   'Forja de hombres',
#   'Des hommes sont nés',
#   'La città dei ragazzi',
#   '少年の町'),
#  ('Q2296177',
#   'Andrey of Gorodets',
#   'human',
#   '',
#   'Andrei Alexandrowitsch von Gorodez',
#   'Andréi III de Vladímir',
#   'André III de Vladimir',
#   'Andrea III di Vladimir',
#   'アンドレイ・アレクサンドロヴィチ'),
#  ('Q14601067',
#   'Gypsy sauce',
#   'condiment',
#   '',
#   'Zigeunersauce',
#   'Salsa zíngara',
#   '',
#   '',
#   ''),
#  ('Q76907',
#   'Henry IV, Count of Luxembourg',
#   'human',
#   'هنري الرابع، كونت لوكسمبورغ',
#   'Heinrich IV.',
#   'Enrique IV de Luxemburgo',
#   'Henri IV de Luxembourg',
#   'Enrico IV di Lussemburgo',
#   'ハインリヒ4世'),
#  ('Q5361036',
#   'SPEC〜Keishichyō Kōanbu Kōandaigoka Mishōjiken Tokubetsugakari Jikenbo〜',
#   'television program',
#   '',
#   '',
#   '',
#   'Keizoku 2: SPEC',
#   '',
#   'SPEC〜警視庁公安部公安第五課 未詳事件特別対策係事件簿〜'),
#  ('Q111490',
#   'Geoffrey Plantagenet, Count of Anjou',
#   'human',
#   'جيفري الخامس كونت أنجو',
#   'Gottfried V.',
#   'Godofredo V de Anjou',
#   "Geoffroy V d'Anjou",
#   "Goffredo V d'Angiò",
#   'ジョフロワ4世'),
#  ('Q20182063',
#   'Maggi seasoning',
#   'sauce',
#   '',
#   'Maggi-Würze',
#   '',
#   '',
#   '',
#   'マギーソース'),
#  ('Q51582',
#   'William Friedkin',
#   'human',
#   'وليم فريدكن',
#   'William Friedkin',
#   'William Friedkin',
#   'William Friedkin',
#   'William Friedkin',
#   'ウィリアム・フリードキン'),
#  ('Q31970512',
#   'Jonathan Majors',
#   'human',
#   'جوناثان ميجورز',
#   'Jonathan Majors',
#   'Jonathan Majors',
#   'Jonathan Majors',
#   'Jonathan Majors',
#   'ジョナサン・メジャース'),
#  ('Q9448',
#   'Premier League',
#   'association football league',
#   'الدوري الإنجليزي الممتاز',
#   'Premier League',
#   'Premier League',
#   "championnat d'Angleterre de football",
#   'Premier League',
#   'プレミアリーグ'),
#  ('Q24228',
#   'Halo Studios',
#   'video game developer',
#   '343 إندستريز',
#   '343 Industries',
#   '343 Industries',
#   '343 Industries',
#   '343 Industries',
#   '343 Industries'),
#  ('Q732997',
#   'British Academy Film Awards',
#   'recurring event',
#   'جوائز الأكاديمية البريطانية للأفلام',
#   'British Academy Film Award',
#   'Premios BAFTA',
#   'British Academy Film Awards',
#   'British Academy Film Awards',
#   '英国アカデミー賞'),
#  ('Q60738660',
#   'The Boy Who Harnessed the Wind',
#   'film',
#   'الصبي الذي سخر الرياح',
#   'Der Junge, der den Wind einfing',
#   'El niño que domó el viento',
#   'Le Garçon qui dompta le vent',
#   'Il ragazzo che catturò il vento',
#   '風をつかまえた少年'),
#  ('Q1216187',
#   'Beauty and the Beast',
#   'television series',
#   'الجميلة والوحش',
#   'Die Schöne und das Biest',
#   'La bella y la bestia',
#   'La Belle et la Bête',
#   'La bella e la bestia',
#   '1987年の同名番組'),
#  ('Q3490213',
#   'Violin Sonata No. 3',
#   'musical work/composition',
#   '',
#   '',
#   'Sonata para violín n.° 3 (Brahms)',
#   'Sonate pour violon et piano n° 3',
#   'Sonata n.3 per violino e pianoforte',
#   'ヴァイオリンソナタ第3番 (ブラームス)'),
#  ('Q104580110',
#   'Ruin and Rising',
#   'literary work',
#   '',
#   'Lodernde Schwingen',
#   '',
#   "L'Oiseau de feu",
#   'Rovina e ascesa',
#   ''),
#  ('Q36479',
#   'The Lion King',
#   'animated film',
#   'الأسد الملك',
#   'Der König der Löwen',
#   'El rey león',
#   'Le Roi lion',
#   'Il re leone',
#   'ライオン・キング'),
#  ('Q7642193',
#   'Super Bowl 50',
#   'Super Bowl',
#   'سوبر بول 50',
#   'Super Bowl 50',
#   'Super Bowl 50',
#   'Super Bowl 50',
#   'Super Bowl 50',
#   '第50回スーパーボウル'),
#  ('Q819972',
#   'The Transporter',
#   'film',
#   'الناقل',
#   'The Transporter',
#   'The Transporter',
#   'Le Transporteur',
#   'The Transporter',
#   'トランスポーター'),
#  ('Q2280840',
#   'Ganbare Genki',
#   'anime television series',
#   'فارس الفتى الشجاع',
#   '',
#   '',
#   '',
#   'Forza Genki - Forza Sugar',
#   'がんばれ元気'),
#  ('Q2444377',
#   'Smolenskoye Orthodox Cemetery',
#   'cemetery',
#   '',
#   'Smolensker Friedhof',
#   'Cementerio Ortodoxo de Smolensk',
#   'cimetière orthodoxe de Smolensk',
#   '',
#   'スモレンスキー墓地'),
#  ('Q1291779',
#   'Al-Zaytuna Mosque',
#   'mosque',
#   'جامع الزيتونة',
#   'Ez-Zitouna-Moschee',
#   'Mezquita Zitouna',
#   'mosquée Zitouna',
#   'moschea al-Zaytuna',
#   'ザイトゥーナモスク'),
#  ('Q1299410',
#   'Investigation of a Citizen Above Suspicion',
#   'film',
#   'تحقيق مع مواطن فوق مستوى الشبهات',
#   'Ermittlungen gegen einen über jeden Verdacht erhabenen Bürger',
#   'Investigación sobre un ciudadano libre de toda sospecha',
#   'Enquête sur un citoyen au-dessus de tout soupçon',
#   'Indagine su un cittadino al di sopra di ogni sospetto',
#   '殺人捜査'),
#  ('Q2270201',
#   'Floris and Blancheflour',
#   'literary work',
#   '',
#   'Floire et Blancheflor',
#   'Flores y Blancaflor',
#   'Floire et Blancheflor',
#   '',
#   ''),
#  ('Q1570778',
#   'Little Princess',
#   'television series',
#   '',
#   'Kleine Prinzessin',
#   'Princesita',
#   'Petite Princesse',
#   '',
#   'リトルプリンセス'),
#  ('Q823691',
#   'The Country of the Blind',
#   'literary work',
#   'بلد العميان',
#   'Das Land der Blinden',
#   'El país de los ciegos',
#   'Le Pays des aveugles',
#   'Il paese dei ciechi',
#   ''),
#  ('Q2492950',
#   'Nine Princes in Amber',
#   'literary work',
#   '',
#   'Corwin von Amber',
#   'Los nueve príncipes de Ámbar',
#   "Les Neuf Princes d'Ambre",
#   'Nove principi in Ambra',
#   ''),
#  ('Q25396205',
#   'Derbent Synagogue',
#   'synagogue',
#   '',
#   'Kele-Numas',
#   'Sinagoga de Derbent',
#   '',
#   '',
#   ''),
#  ('Q127912',
#   'United States Declaration of Independence',
#   'declaration of independence',
#   'إعلان الاستقلال الأمريكي',
#   'Unabhängigkeitserklärung der Vereinigten Staaten',
#   'Declaración de Independencia de los Estados Unidos',
#   "Déclaration d'indépendance des États-Unis",
#   "Dichiarazione d'indipendenza degli Stati Uniti d'America",
#   'アメリカ独立宣言'),
#  ('Q3834368',
#   'bounty hunter',
#   'fictional profession',
#   '',
#   'Kopfgeldjäger',
#   'Cazarrecompensas (Star Wars)',
#   '',
#   'Lista di cacciatori di taglie minori (Guerre stellari)',
#   ''),
#  ('Q2071759',
#   'Cool Air',
#   'literary work',
#   'الهواء البارد',
#   '',
#   'Aire frío',
#   'Air froid',
#   'Aria fredda',
#   '冷気'),
#  ('Q52847',
#   'European Economic Community',
#   'organization',
#   'السوق الأوروبية المشتركة',
#   'Europäische Wirtschaftsgemeinschaft',
#   'Comunidad Económica Europea',
#   'Communauté économique européenne',
#   'Comunità economica europea',
#   '欧州経済共同体'),
#  ('Q66364576',
#   '2019 World Series',
#   'sports competition',
#   'سلسلة العالم لكرة القاعدة 2019',
#   'World Series 2019',
#   'Serie Mundial de 2019',
#   'Série mondiale 2019',
#   'World Series 2019',
#   '2019年のワールドシリーズ'),
#  ('Q2478988',
#   'Mole Man',
#   'comics character',
#   '',
#   '',
#   'Hombre Topo',
#   "L'Homme-taupe",
#   'Uomo Talpa',
#   'モールマン'),
#  ('Q645157',
#   'Poblet Monastery',
#   'church building',
#   '',
#   'Monestir de Santa Maria de Poblet',
#   'Monasterio de Poblet',
#   'monastère de Poblet',
#   'Monastero di Santa Maria di Poblet',
#   'ポブレー修道院'),
#  ('Q377882',
#   'Royaumont Abbey',
#   'abbey',
#   '',
#   'Kloster Royaumont',
#   '',
#   'abbaye de Royaumont',
#   'Abbazia di Royaumont',
#   'ロワイヨモン修道院'),
#  ('Q352940',
#   'Louis of Evreux',
#   'human',
#   'لويس، كونت إفرو',
#   'Ludwig',
#   'Luis de Évreux',
#   "Louis d'Évreux",
#   "Luigi d'Évreux",
#   'ルイ・デヴルー'),
#  ('Q154581',
#   'Gangs of New York',
#   'film',
#   'عصابات نيويورك',
#   'Gangs of New York',
#   'Gangs of New York',
#   'Gangs of New York',
#   'Gangs of New York',
#   'ギャング・オブ・ニューヨーク'),
#  ('Q1356213',
#   'Mission: Impossible',
#   'film series',
#   'مهمة مستحيلة',
#   'Mission: Impossible',
#   'Misión imposible',
#   'Mission impossible',
#   'Mission: Impossible',
#   'ミッション:インポッシブルシリーズ'),
#  ('Q43228',
#   'Goodbye, Mr. Chips',
#   'film',
#   'الوداع يا سيد تشيبس',
#   'Auf Wiedersehen, Mr. Chips',
#   'Adiós, Mr. Chips',
#   'Au revoir Mr. Chips',
#   'Addio, Mr. Chips!',
#   'チップス先生さようなら'),
#  ('Q426433',
#   'Not as a Stranger',
#   'film',
#   '',
#   '… und nicht als ein Fremder',
#   'No serás un extraño',
#   'Pour que vivent les hommes',
#   'Nessuno resta solo',
#   '見知らぬ人でなく'),
#  ('Q6818188',
#   'María Mercedes Fontecilla Valdivieso',
#   'human',
#   '',
#   'Mercedes Fontecilla',
#   'María Mercedes Fontecilla Valdivieso',
#   'María Mercedes Fontecilla Valdivieso',
#   '',
#   ''),
#  ('Q7828545',
#   "Toucan 'Tecs",
#   'television series',
#   'الصديقان',
#   'The Adventures of Zippi and Zac',
#   '',
#   '',
#   '',
#   ''),
#  ('Q495840',
#   'Little Johnny',
#   'stock character',
#   '',
#   'Jantje',
#   'Jaimito',
#   'blague de Toto',
#   'Pierino',
#   '小さなジョニー'),
#  ('Q153204',
#   'Emilian of Cogolla',
#   'human',
#   'مييان',
#   'Aemilianus von Cogolla',
#   'Millán',
#   'Émilien de la Cogolla',
#   'Emiliano della Cogolla',
#   '聖エミリアヌス'),
#  ('Q778527',
#   'Eros and Civilization',
#   'written work',
#   'الحب والحضارة',
#   'Triebstruktur und Gesellschaft',
#   'Eros y civilización',
#   'Éros et civilisation',
#   'Eros e civiltà',
#   ''),
#  ('Q2625582',
#   'Dumuzid the Fisherman',
#   'human',
#   'دوموزيد الصياد',
#   '',
#   'Dumuzid, el pescador',
#   'Dumuzi le Pêcheur',
#   '',
#   'ドゥムジ (メソポタミア神話)'),
#  ('Q1272037',
#   'Self-portrait at Thirteen',
#   'drawing',
#   '',
#   'Selbstbildnis als Dreizehnjähriger',
#   'autorretrato de Durero',
#   "Autoportrait à l'âge de 13 ans",
#   'Autoritratto a tredici anni',
#   ''),
#  ('Q205524',
#   'Royal Convent of La Encarnación',
#   'monastery',
#   '',
#   'Real Monasterio de la Encarnación',
#   'Real Monasterio de la Encarnación',
#   "monastère de l'Incarnation",
#   'Monastero Reale de la Encarnación',
#   'ラ・エンカルナシオン王立修道院'),
#  ('Q573463',
#   'Anthony Joshua',
#   'human',
#   'أنتوني جوشوا',
#   'Anthony Joshua',
#   'Anthony Joshua',
#   'Anthony Joshua',
#   'Anthony Joshua',
#   'アンソニー・ジョシュア'),
#  ('Q6191409',
#   'Jia Tanchun',
#   'fictional human',
#   '',
#   '',
#   '',
#   'Jia Désir du Printemps',
#   '',
#   '賈探春'),
#  ('Q221150',
#   'Minnesota Vikings',
#   'American football team',
#   'مينيسوتا فايكنغز',
#   'Minnesota Vikings',
#   'Minnesota Vikings',
#   'Vikings du Minnesota',
#   'Minnesota Vikings',
#   'ミネソタ・バイキングス'),
#  ('Q163689',
#   'Violin Concerto No. 1',
#   'musical work/composition',
#   '',
#   '1. Violinkonzert',
#   'Concierto para violín n.º 1 (Bruch)',
#   'Concerto pour violon nº 1 de Bruch',
#   'Concerto per violino e orchestra (Bruch)',
#   'ヴァイオリン協奏曲第1番 (ブルッフ)'),
#  ('Q2305473',
#   'Bodrum Mosque',
#   'mosque',
#   'جامع بودروم',
#   'Myrelaion',
#   'Mezquita de Bodrum',
#   'mosquée Bodrum',
#   'moschea Bodrum',
#   ''),
#  ('Q333980',
#   'Jumièges Abbey',
#   'abbey',
#   '',
#   'Abtei Jumièges',
#   'Abadía de Jumièges',
#   'abbaye de Jumièges',
#   'abbazia di Jumièges',
#   'ジュミエージュ修道院'),
#  ('Q736865',
#   'Zeus: Master of Olympus',
#   'video game',
#   'زيوس: السيد في أوليمبوس',
#   'Herrscher des Olymp – Zeus',
#   'Señor del Olimpo - Zeus',
#   "Le Maître de l'Olympe : Zeus",
#   "Signore dell'Olimpo - Zeus",
#   ''),
#  ('Q4115461',
#   'Prophet Joseph',
#   'television series',
#   'يوسف الصديق',
#   'Yousuf e Payambar',
#   'José el Profeta',
#   'Prophète Joseph',
#   '',
#   ''),
#  ('Q739122',
#   'Designing Women',
#   'television series',
#   'ديزاينينغ وومين',
#   'Mann muss nicht sein',
#   '',
#   "Femmes d'affaires et Dames de cœur",
#   'Quattro donne in carriera',
#   '浮気なおしゃれミディ'),
#  ('Q81689',
#   'The Da Vinci Code',
#   'literary work',
#   'شيفرة دا فينشي',
#   'Sakrileg',
#   'El código Da Vinci',
#   'Da Vinci Code',
#   'Il codice da Vinci',
#   'ダ・ヴィンチ・コード'),
#  ('Q4186950',
#   'The Man in the Moone',
#   'literary work',
#   '',
#   '',
#   'El hombre en la Luna',
#   'L’Homme dans la lune',
#   'The Man in the Moone',
#   '月の男'),
#  ('Q334038',
#   'Marienstatt Abbey',
#   'monastery',
#   '',
#   'Zisterzienserkloster Marienstatt',
#   '',
#   '',
#   '',
#   ''),
#  ('Q9056689',
#   'alphabet pasta',
#   'food',
#   'معكرونة الحروف',
#   'Buchstabennudeln',
#   'pasta de letras',
#   'pâte alimentaire alphabet',
#   'Alfabeto (pasta)',
#   'アルファベットパスタ'),
#  ('Q650855',
#   'Detroit Tigers',
#   'baseball team',
#   'ديترويت تايجرز',
#   'Detroit Tigers',
#   'Detroit Tigers',
#   'Tigers de Détroit',
#   'Detroit Tigers',
#   'デトロイト・タイガース'),
#  ('Q759',
#   'New Hampshire',
#   'U.S. state',
#   'نيوهامبشير',
#   'New Hampshire',
#   'Nuevo Hampshire',
#   'New Hampshire',
#   'New Hampshire',
#   'ニューハンプシャー州'),
#  ('Q17512899',
#   'Dan Leno and the Limehouse Golem',
#   'literary work',
#   'دان لينو والغول الجيري',
#   '',
#   '',
#   'Le Golem de Londres',
#   '',
#   '切り裂き魔ゴーレム'),
#  ('Q7446942',
#   'Seishiro Kato',
#   'human',
#   '',
#   'Seishirō Katō',
#   'Seishirō Katō',
#   'Seishirō Katō',
#   'Seishirō Katō',
#   '加藤清史郎'),
#  ('Q1402878',
#   'The Birthday',
#   'hardback',
#   'ذا بيرثداي',
#   '',
#   '',
#   '',
#   'Bāsudei',
#   'バースデイ'),
#  ('Q78635',
#   'Archduke Felix of Austria',
#   'human',
#   'أرشيدوق فيليكس من النمسا',
#   'Felix Habsburg-Lothringen',
#   'Félix de Hasburgo',
#   'Félix de Habsbourg-Lorraine',
#   "Felice d'Asburgo-Lorena",
#   'フェリックス・ハプスブルク＝ロートリンゲン'),
#  ('Q1258295',
#   'Thirty Seconds Over Tokyo',
#   'film',
#   '',
#   'Dreißig Sekunden über Tokio',
#   'Treinta segundos sobre Tokio',
#   'Trente Secondes sur Tokyo',
#   'Missione segreta',
#   '東京上空三十秒'),
#  ('Q10230',
#   'Bharatiya Janata Party',
#   'political party',
#   'حزب بهاراتيا جاناتا',
#   'Bharatiya Janata Party',
#   'Partido Popular Indio',
#   'Bharatiya Janata Party',
#   'Partito Popolare Indiano',
#   'インド人民党'),
#  ('Q1812482',
#   "Everybody's Changing",
#   'single',
#   '',
#   "Everybody's Changing",
#   "Everybody's Changing",
#   "Everybody's Changing",
#   "Everybody's Changing",
#   ''),
#  ('Q32522',
#   'Jennifer Aniston',
#   'human',
#   'جينيفر أنيستون',
#   'Jennifer Aniston',
#   'Jennifer Aniston',
#   'Jennifer Aniston',
#   'Jennifer Aniston',
#   'ジェニファー・アニストン'),
#  ('Q3301984',
#   "Man's Best Friend",
#   'film',
#   '',
#   'Der Tod kommt auf vier Pfoten',
#   '',
#   "Max, le meilleur ami de l'homme",
#   '',
#   '未確認生命体 MAX/マックス'),
#  ('Q34664',
#   'Hiroshima',
#   'city designated by government ordinance',
#   'هيروشيما',
#   'Hiroshima',
#   'Hiroshima',
#   'Hiroshima',
#   'Hiroshima',
#   '広島市'),
#  ('Q435016',
#   'Augustus, Elector of Saxony',
#   'human',
#   'أغسطس، ناخب ساكسونيا',
#   'August von Sachsen',
#   'Augusto de Sajonia',
#   'Auguste Ier',
#   'Augusto I di Sassonia',
#   'アウグスト'),
#  ('Q41644',
#   'Warsaw Pact',
#   'international organization',
#   'حلف وارسو',
#   'Warschauer Pakt',
#   'Pacto de Varsovia',
#   'Pacte de Varsovie',
#   'patto di Varsavia',
#   'ワルシャワ条約機構'),
#  ('Q1056344',
#   'Florence Charterhouse',
#   'Carthusian monastery',
#   '',
#   'Certosa San Lorenzo di Galluzzo',
#   'La cartuja de Florencia',
#   'chartreuse de Galluzzo',
#   'certosa di Firenze',
#   ''),
#  ('Q5800956',
#   'Basilica of the National Shrine of Our Lady of Coromoto',
#   'minor basilica',
#   '',
#   'Basilika Unserer Lieben Frau von Coromoto',
#   'Santuario Nacional Nuestra Señora de Coromoto',
#   'basilique Notre-Dame-de-Coromoto',
#   '',
#   ''),
#  ('Q23884740',
#   'Luke Combs',
#   'human',
#   'لوك كومبز',
#   'Luke Combs',
#   'Luke Combs',
#   'Luke Combs',
#   'Luke Combs',
#   'ルーク・コムズ'),
#  ('Q1534510',
#   "The Devil's Rejects",
#   'film',
#   'منبوذو الشيطان',
#   'The Devil’s Rejects',
#   "The Devil's Rejects",
#   "The Devil's Rejects",
#   'La casa del diavolo',
#   'デビルズ・リジェクト マーダー・ライド・ショー2'),
#  ('Q354639',
#   'Minolta SR-mount',
#   'technical standard',
#   '',
#   'Minolta SR-Bajonett',
#   '',
#   'Monture Minolta SR',
#   'attacco Minolta SR',
#   ''),
#  ('Q1909623',
#   'Matthew Stover',
#   'human',
#   'ماثيو ستوفر',
#   'Matthew Stover',
#   'Matthew Stover',
#   'Matthew Stover',
#   'Matthew Stover',
#   ''),
#  ('Q210210',
#   'Concerto for Piano and Orchestra no. 2 in F minor, op. 21',
#   'musical work/composition',
#   '',
#   '2. Klavierkonzert',
#   'Concierto para piano n.º 2',
#   'Concerto pour piano nº 2 de Chopin',
#   'Concerto per pianoforte n. 2 op. 21',
#   'ピアノ協奏曲第2番'),
#  ('Q324119',
#   'Volkenroda Abbey',
#   'monastery',
#   '',
#   'Zisterzienserkloster Volkenroda',
#   '',
#   'monastère de Volkenroda',
#   '',
#   ''),
#  ('Q2757215',
#   '2008 Masters Tournament',
#   'Masters Tournament',
#   '',
#   '',
#   '',
#   'Masters de golf de 2008',
#   '',
#   '2008マスターズ・トーナメント'),
#  ('Q17027987',
#   'The Rogue Prince',
#   'literary work',
#   'الأمير المارق',
#   '',
#   'El Príncipe Pícaro',
#   '',
#   '',
#   '王弟'),
#  ('Q280872',
#   'Timon of Phlius',
#   'human',
#   '',
#   'Timon von Phleius',
#   'Timón el Silógrafo',
#   'Timon de Phlionte',
#   'Timone di Fliunte',
#   'プリウスのティモン'),
#  ('Q17',
#   'Japan',
#   'sovereign state',
#   'اليابان',
#   'Japan',
#   'Japón',
#   'Japon',
#   'Giappone',
#   '日本'),
#  ('Q695405',
#   'Rumours',
#   'album',
#   '',
#   'Rumours',
#   'Rumours',
#   'Rumours',
#   'Rumours',
#   '噂'),
#  ('Q930276',
#   'Lombard Street',
#   'architectural landmark',
#   'شارع لومبارد',
#   'Lombard Street',
#   'Lombard Street',
#   'Lombard Street',
#   'Lombard Street',
#   'ロンバード・ストリート'),
#  ('Q322678',
#   'Our Lady of Altötting',
#   'chapel',
#   '',
#   'Gnadenkapelle',
#   'Capilla de Nuestra Señora de Altötting',
#   "sanctuaire Notre-Dame d'Altötting",
#   'cappella delle Grazie',
#   'アルテッティングの聖母巡礼聖堂'),
#  ('Q919407',
#   'wicked fairy godmother',
#   'folklore character',
#   '',
#   'Karabossa',
#   '',
#   'fée Carabosse',
#   'Fata cattiva',
#   ''),
#  ('Q5117080',
#   'Church of Saint Anthony of the Germans',
#   'Catholic church building',
#   '',
#   '',
#   'Iglesia de San Antonio de los Alemanes',
#   'église St Antoine des Allemands',
#   "chiesa di Sant'Antonio degli Alemanni",
#   'サン・アントニオ・デ・ロス・ポルトゥゲーセス聖堂'),
#  ('Q19320',
#   'The Little Devil',
#   'film',
#   '',
#   'Ein himmlischer Teufel',
#   'Il piccolo diavolo',
#   'Le Petit Diable',
#   'Il piccolo diavolo',
#   ''),
#  ('Q235128',
#   'Infanta María de las Mercedes, Countess of Barcelona',
#   'human',
#   'الأميرة ماريا مرسيديس دي الصقليتين',
#   'María de las Mercedes de Borbón y Orléans',
#   'María de las Mercedes de Borbón',
#   'María de las Mercedes de Bourbon-Siciles',
#   'Maria di Borbone',
#   'マリア・デ・ラス・メルセデス・デ・ボルボーン＝ドス・シシリアス'),
#  ('Q246511',
#   'Symphony No. 6',
#   'musical work/composition',
#   '',
#   '6. Sinfonie',
#   'Sinfonía n.º 6',
#   'Symphonie nº 6 de Prokofiev',
#   "Sinfonia n. 6 (Prokof'ev)",
#   '交響曲第6番'),
#  ('Q3230961',
#   'Underworld U.S.A.',
#   'film',
#   '',
#   'Alles auf eine Karte',
#   '',
#   'Les Bas-fonds new-yorkais',
#   'La vendetta del gangster',
#   '殺人地帯U・S・A'),
#  ('Q641315',
#   'Spirit: Stallion of the Cimarron',
#   'animated film',
#   'سبيريت: حصان من سيمارون',
#   'Spirit – Der wilde Mustang',
#   'Spirit: el corcel indomable',
#   "Spirit, l'étalon des plaines",
#   'Spirit - Cavallo selvaggio',
#   'スピリット'),
#  ('Q260205',
#   'The Jungle',
#   'literary work',
#   'الأدغال',
#   'Der Dschungel',
#   'La Jungla',
#   'La Jungle',
#   'La giungla',
#   'ジャングル'),
#  ('Q271725',
#   'Mr. Olympia',
#   'recurring sporting event',
#   'مستر أولمبيا',
#   'Mr. Olympia',
#   'Mister Olympia',
#   'Mr. Olympia',
#   'Mister Olympia',
#   'ミスター・オリンピア'),
#  ('Q599095',
#   'Deep Blue Sea',
#   'film',
#   'بحر ازرق عميق',
#   'Deep Blue Sea',
#   'Deep Blue Sea',
#   'Peur bleue',
#   'Blu profondo',
#   'ディープ・ブルー'),
#  ('Q3687260',
#   'Consider the Lobster',
#   'written work',
#   '',
#   '',
#   'Hablemos de langostas',
#   'Considérations sur le homard',
#   "Considera l'aragosta",
#   ''),
#  ('Q3772823',
#   'Wang Xifeng',
#   'fictional human',
#   '',
#   '',
#   '',
#   'Wang Phénix triomphal',
#   '',
#   '王熙鳳'),
#  ('Q2551859',
#   'Miraflores Charterhouse',
#   'Carthusian monastery',
#   '',
#   'Kartause Miraflores',
#   'Cartuja de Santa María de Miraflores',
#   'chartreuse Santa María de Miraflores',
#   'certosa di Miraflores',
#   ''),
#  ('Q263203',
#   'red cabbage',
#   'taxon',
#   'ملفوف أحمر',
#   'Rotkohl',
#   'col lombarda',
#   'chou rouge',
#   'cavolo rosso',
#   '赤キャベツ'),
#  ('Q31190329',
#   'Taksim Mosque',
#   'mosque',
#   'مسجد تقسيم',
#   'Taksim-Moschee',
#   '',
#   '',
#   'Moschea di Taksim',
#   'タクスィムモスク'),
#  ('Q2042566',
#   'Farmer in the Sky',
#   'literary work',
#   '',
#   'Pioniere im Weltall',
#   'El granjero de las estrellas',
#   'Pommiers dans le ciel',
#   'Pionieri dello spazio',
#   'ガニメデの少年'),
#  ('Q296555',
#   'Philippe, Duke of Orléans',
#   'human',
#   'فيليب الأول، دوق أورليان',
#   'Philippe I. de Bourbon, duc d’Orléans',
#   'Felipe I de Orleans',
#   "Philippe d'Orléans",
#   'Filippo I di Borbone-Orléans',
#   'フィリップ1世'),
#  ('Q2283930',
#   'Venusaur',
#   'grass-type Pokémon',
#   '',
#   'Bisaflor',
#   'Venusaur',
#   'Florizarre',
#   'Venusaur',
#   'フシギバナ'),
#  ('Q151114',
#   'The Wall',
#   'album',
#   'ذا وول',
#   'The Wall',
#   'The Wall',
#   'The Wall',
#   'The Wall',
#   'ザ・ウォール'),
#  ('Q225373',
#   'Kykkos Monastery',
#   'monastery',
#   'دير كيكوس',
#   'Kloster Kykkos',
#   'Monasterio de Kikkos',
#   'monastère de Kykkos',
#   'Monastero di Kykkos',
#   'キッコス修道院'),
#  ('Q1091065',
#   'Weirdsister College',
#   'television series',
#   '',
#   'Die Hochschule der Komischen Schwestern',
#   '',
#   '',
#   '',
#   'ウィアードシスターズ・カレッジ'),
#  ('Q333912',
#   'Floreffe Abbey',
#   'monastery',
#   '',
#   'Abtei Floreffe',
#   '',
#   'abbaye de Floreffe',
#   '',
#   ''),
#  ('Q1105407',
#   'Curious George',
#   'fictional monkey',
#   '',
#   'Coco – Der neugierige Affe',
#   'Jorge el curioso',
#   'Georges le singe',
#   '',
#   'ひとまねこざる'),
#  ('Q23010088',
#   'Spider-Man: Homecoming',
#   'film',
#   'الرجل العنكبوت: العودة للوطن',
#   'Spider-Man: Homecoming',
#   'Spider-Man: Homecoming',
#   'Spider-Man: Homecoming',
#   'Spider-Man: Homecoming',
#   'スパイダーマン:ホームカミング'),
#  ('Q59346',
#   'The Mortal Instruments: City of Bones',
#   'film',
#   'الأدوات المميتة: مدينة العظام',
#   'Chroniken der Unterwelt – City of Bones',
#   'Cazadores de sombras: Ciudad de hueso',
#   'The Mortal Instruments : La Cité des ténèbres',
#   'Shadowhunters - Città di ossa',
#   'シャドウハンター'),
#  ('Q69319',
#   'John Kasich',
#   'human',
#   'جون كيسيك',
#   'John Kasich',
#   'John Kasich',
#   'John Kasich',
#   'John Kasich',
#   'ジョン・ケーシック'),
#  ('Q1994481',
#   'Bullet Bill',
#   'fictional species',
#   '',
#   'Kugel Willi',
#   'Bill Bala',
#   '',
#   'Pallottolo Bill',
#   'キラー (ゲームキャラクター)'),
#  ('Q1124',
#   'Bill Clinton',
#   'human',
#   'بيل كلينتون',
#   'Bill Clinton',
#   'Bill Clinton',
#   'Bill Clinton',
#   'Bill Clinton',
#   'ビル・クリントン'),
#  ('Q467', 'woman', 'adult', 'امرأة', 'Frau', 'mujer', 'femme', 'donna', '女性'),
#  ('Q940186',
#   'Breakheart Pass',
#   'film',
#   '',
#   'Nevada Pass',
#   'Nevada Express',
#   'Le Solitaire de Fort Humboldt',
#   'Io non credo a nessuno',
#   '軍用列車'),
#  ('Q85808226',
#   "The Queen's Gambit",
#   'miniseries',
#   'مناورة الملكة',
#   'Das Damengambit',
#   'Gambito de Reina',
#   'Le Jeu de la dame',
#   'La regina degli scacchi',
#   'クイーンズ・ギャンビット (ドラマ)'),
#  ('Q3235392',
#   'The Rediscovery of Man',
#   'written work',
#   '',
#   '',
#   '',
#   "Les Seigneurs de l'instrumentalité",
#   '',
#   ''),
#  ('Q2471799',
#   'Ketchaoua Mosque',
#   'mosque',
#   'جامع كتشاوة',
#   'Ketschawa-Moschee',
#   'Mezquita de Ketchaoua',
#   'mosquée Ketchaoua',
#   'moschea Ketchaoua',
#   ''),
#  ('Q188',
#   'German',
#   'language',
#   'الألمانية',
#   'Deutsch',
#   'alemán',
#   'allemand',
#   'tedesco',
#   'ドイツ語'),
#  ('Q905',
#   'Franz Kafka',
#   'human',
#   'فرانس كافكا',
#   'Franz Kafka',
#   'Franz Kafka',
#   'Franz Kafka',
#   'Franz Kafka',
#   'フランツ・カフカ'),
#  ('Q105620963',
#   'I am Jalaliddin',
#   'television series',
#   'منديرمان جلال الدين',
#   'Mendirman Jaloliddin',
#   '',
#   '',
#   '',
#   ''),
#  ('Q1265755',
#   'The Theory of the Leisure Class',
#   'written work',
#   'نظرية الطبقة المترفة',
#   'Theorie der feinen Leute',
#   'Teoría de la clase ociosa',
#   'Théorie de la classe de loisir',
#   '',
#   '有閑階級の理論'),
#  ('Q1758561',
#   'Serenade for Strings',
#   'musical work/composition',
#   '',
#   '',
#   'Serenata para cuerdas (Dvořák)',
#   'Sérénade pour cordes',
#   'Serenata per archi',
#   '弦楽セレナーデ'),
#  ('Q2891563',
#   'Batman & Dracula trilogy',
#   'graphic novel',
#   'ثلاثية باتمان ودراكولا',
#   '',
#   'Batman & Drácula: lluvia roja',
#   'Batman et Dracula : Pluie de sang',
#   'Batman: Vampiro',
#   ''),
#  ('Q833178',
#   'Schäftlarn Abbey',
#   'abbey',
#   '',
#   'Prämonstratenserstift Schäftlarn',
#   'Abadía de Schäftlarn',
#   'abbaye de Schäftlarn',
#   '',
#   'シェフトラルン修道院'),
#  ('Q164177',
#   'Phoenix Suns',
#   'basketball team',
#   'فينيكس صنز',
#   'Phoenix Suns',
#   'Phoenix Suns',
#   'Suns de Phoenix',
#   'Phoenix Suns',
#   'フェニックス・サンズ'),
#  ('Q1645774',
#   'House Greyjoy',
#   'fictional noble family',
#   'آل غريجوي',
#   '',
#   'Casa Greyjoy',
#   '',
#   'Casa Greyjoy',
#   ''),
#  ('Q820238',
#   '21 Hours at Munich',
#   'film',
#   '21 ساعة في ميونخ',
#   'Die 21 Stunden von München',
#   '21 horas en Munich',
#   'Les 21 Heures de Munich',
#   '21 ore a Monaco',
#   'テロリスト・黒い九月'),
#  ('Q3477975',
#   'Sixteen Waltzes, Op. 39',
#   'musical work/composition',
#   '',
#   'Sechzehn Walzer für Klavier',
#   'Dieciséis valses, op. 39',
#   'Seize valses pour piano à quatre mains',
#   'Sedici valzer',
#   'ワルツ集 (ブラームス)'),
#  ('Q361149',
#   'Gene Wolfe',
#   'human',
#   'جين ولف',
#   'Gene Wolfe',
#   'Gene Wolfe',
#   'Gene Wolfe',
#   'Gene Wolfe',
#   'ジーン・ウルフ'),
#  ('Q71084',
#   'First French Empire',
#   'historical country',
#   'الإمبراطورية الفرنسية الأولى',
#   'Erstes Kaiserreich',
#   'Primer Imperio francés',
#   'Premier Empire français',
#   'Primo Impero francese',
#   'フランス第一帝政'),
#  ('Q1048557',
#   "Maeterlinck's Blue Bird: Tyltyl and Mytyl's Adventurous Journey",
#   'anime television series',
#   '',
#   'Mêterurinku no aoi tori: Chiruchiru Michiru no bôken ryokô',
#   '',
#   "L'Oiseau bleu",
#   "L'uccellino azzurro",
#   'メーテルリンクの青い鳥 チルチルミチルの冒険旅行'),
#  ('Q1670321',
#   'St. George Utah Temple',
#   'temple',
#   '',
#   'St.-George-Utah-Tempel',
#   'Templo de St. George',
#   'temple mormon de Saint George',
#   '',
#   ''),
#  ('Q3490244',
#   'Cello Sonata No. 2',
#   'musical work/composition',
#   '',
#   '',
#   '',
#   'Sonate pour violoncelle et piano nº 2',
#   '',
#   'チェロソナタ第2番 (メンデルスゾーン)'),
#  ('Q3390587',
#   'Agent J',
#   'comics character',
#   '',
#   'Agent J',
#   'Agente J',
#   'Agent J',
#   'Agente J',
#   'エージェントJ'),
#  ('Q6534',
#   'French Revolution',
#   'historical event',
#   'الثورة الفرنسية',
#   'Französische Revolution',
#   'Revolución francesa',
#   'Révolution française',
#   'rivoluzione francese',
#   'フランス革命'),
#  ('Q168562',
#   'Command & Conquer',
#   'video game series',
#   'كوماند أند كنكر',
#   'Command & Conquer',
#   'Command & Conquer',
#   'Command and Conquer',
#   'Command & Conquer',
#   'コマンド&コンカー'),
#  ('Q2820392',
#   "St. Joseph's Abbey",
#   'Trappist monastery',
#   '',
#   'Trappistenabtei Spencer',
#   'abadía de San José',
#   'abbaye Saint-Joseph',
#   '',
#   'セントジョゼフ修道院'),
#  ('Q6167871',
#   'The Spiral Road',
#   'film',
#   '',
#   'Am Schwarzen Fluss',
#   'Camino de la jungla',
#   "L'Homme de Bornéo",
# ...
#   'mar Mediterraneo',
#   '地中海'),
#  ('Q2087411',
#   'Twelve Collegia',
#   'building',
#   '',
#   '',
#   'Doce Colegios de San Petersburgo',
#   'Douze Collèges',
#   'Dodici Collegi',
#   '12棟の学院館'),
#  ('Q6498672',
#   'Laura Beale',
#   'fictional human',
#   '',
#   '',
#   'Laura Dunn',
#   '',
#   '',
#   ''),
#  ('Q11272884',
#   "The Pilot's Love Song",
#   'media franchise',
#   'أغنية حب الطيار',
#   '',
#   'Toaru Hikūshi e no Koiuta',
#   '',
#   'Toaru hikūshi e no koiuta',
#   'とある飛空士への恋歌'),
#  ('Q15079316',
#   'In the Heart of the Sea',
#   'film',
#   'في قلب الحوت',
#   'Im Herzen der See',
#   'En el Corazón del Mar',
#   "Au cœur de l'océan",
#   'Heart of the Sea - Le origini di Moby Dick',
#   '白鯨のいた海'),
#  ('Q16709559',
#   'Nich Yaka Misyachna',
#   'musical work/composition',
#   '',
#   '',
#   'Noche de luna',
#   'Nitch iaka missiatchna',
#   '',
#   ''),
#  ('Q107526203',
#   'Action Scene',
#   'television series',
#   '',
#   'Die Hart',
#   'Muere, Hart',
#   '',
#   '',
#   ''),
#  ('Q18389',
#   'New England',
#   'cultural area',
#   'إنجلترا الجديدة',
#   'Neuengland',
#   'Nueva Inglaterra',
#   'Nouvelle-Angleterre',
#   'Nuova Inghilterra',
#   'ニューイングランド'),
#  ('Q7542880',
#   'Small Sacrifices',
#   'television film',
#   'تضحيات صغيرة (فيلم)',
#   'Schrei am Abgrund',
#   'Pequeños sacrificios',
#   'On a tué mes enfants',
#   '',
#   'ファラ・フォーセット/薔薇の秘密'),
#  ('Q704183',
#   'Gerard, Duke of Lorraine',
#   'human',
#   '',
#   'Gerhard',
#   'Gerardo de Lorena',
#   'Gérard de Lorraine',
#   'Gerardo di Lorena',
#   'ジェラール'),
#  ('Q918052',
#   'The Martian Chronicles',
#   'literary work',
#   'السجلات المريخية',
#   'Die Mars-Chroniken',
#   'Crónicas marcianas',
#   'Chroniques martiennes',
#   'Cronache marziane',
#   '火星年代記'),
#  ('Q2053228',
#   'Bishop Myriel',
#   'fictional human',
#   'الأسقف ميريل',
#   '',
#   'Évêque Myriel',
#   'Bienvenu Myriel',
#   'Vescovo Myriel',
#   'ミリエル司教'),
#  ('Q2942473',
#   "St John's Cathedral",
#   'Anglican or Episcopal cathedral',
#   '',
#   '',
#   '',
#   'cathédrale Saint John de Hong Kong',
#   '',
#   '聖ヨハネ座堂 (香港)'),
#  ('Q2325522',
#   'Father Time',
#   'personification',
#   '',
#   '',
#   'Padre Tiempo',
#   '',
#   'Padre Tempo',
#   '時の翁'),
#  ('Q30',
#   'United States of America',
#   'sovereign state',
#   'الولايات المتحدة',
#   'Vereinigte Staaten',
#   'Estados Unidos',
#   'États-Unis',
#   "Stati Uniti d'America",
#   'アメリカ合衆国'),
#  ('Q51613',
#   'Epistle to the Philippians',
#   'literary work',
#   'الرسالة إلى أهل فيلبي',
#   'Brief des Paulus an die Philipper',
#   'Epístola a los Filipenses',
#   'Épître aux Philippiens',
#   'Lettera ai Filippesi',
#   'フィリピの信徒への手紙'),
#  ('Q473964',
#   'Osterby Man',
#   'human',
#   '',
#   'Mann von Osterby',
#   'Hombre de Osterby',
#   "homme d'Osterby",
#   '',
#   'オスタービーマン'),
#  ('Q2525430',
#   'Order of Courage',
#   'order',
#   'نيشان الشجاعة',
#   'Tapferkeitsorden',
#   'Orden del Coraje',
#   'ordre du Courage',
#   'ordine del coraggio',
#   '勇気の勲章'),
#  ('Q731482',
#   'Infinity Ward',
#   'video game developer',
#   'إنفنتي وورد',
#   'Infinity Ward',
#   'Infinity Ward',
#   'Infinity Ward',
#   'Infinity Ward',
#   'Infinity Ward'),
#  ('Q371278',
#   'Love Me If You Dare',
#   'film',
#   'أحبني إن كنت تجرؤ',
#   'Liebe mich, wenn du dich traust',
#   'Quiéreme si te atreves',
#   "Jeux d'enfants",
#   'Amami se hai coraggio',
#   '世界でいちばん不運で幸せな私'),
#  ('Q2603313',
#   'Doomsday Book',
#   'literary work',
#   '',
#   '',
#   'El libro del día del Juicio Final',
#   'Le Grand Livre',
#   "L'anno del contagio",
#   'ドゥームズデイ・ブック'),
#  ('Q2375145',
#   'Sokolniki Park',
#   'park',
#   '',
#   '',
#   '',
#   'parc Sokolniki',
#   "Parco Sokol'niki",
#   'ソコルニキ公園'),
#  ('Q5570356',
#   'Global Guardians',
#   'group of fictional characters',
#   '',
#   '',
#   'Global Guardians',
#   '',
#   'Guardiani del Globo',
#   'グローバル・ガーディアンズ'),
#  ('Q13912',
#   'Where the Wild Things Are',
#   'literary work',
#   'حيث تكون الأشياء البرية',
#   'Wo die wilden Kerle wohnen',
#   'Donde viven los monstruos',
#   'Max et les Maximonstres',
#   'Nel paese dei mostri selvaggi',
#   'かいじゅうたちのいるところ'),
#  ('Q176418',
#   'Missa brevis Sancti Joannis de Deo',
#   'musical work/composition',
#   '',
#   'Kleine Orgelsolomesse',
#   '',
#   '',
#   '',
#   '小オルガン・ミサ'),
#  ('Q844836',
#   'The Merry Wives of Windsor',
#   'dramatic work',
#   'زوجات وندسور المرحات',
#   'Die lustigen Weiber von Windsor',
#   'Las alegres comadres de Windsor',
#   'Les Joyeuses Commères de Windsor',
#   'Le allegre comari di Windsor',
#   'ウィンザーの陽気な女房たち'),
#  ('Q500983',
#   'Faisal Mosque',
#   'mosque',
#   'مسجد الملك فيصل',
#   'Faisal-Moschee',
#   'Mezquita Faisal',
#   'mosquée Faisal',
#   'moschea Faysal',
#   'ファイサル・モスク'),
#  ('Q6146073',
#   'James the Red Engine',
#   'anthropomorphic rail vehicle',
#   '',
#   '',
#   'James la Locomotora Roja',
#   '',
#   '',
#   'ジェームス'),
#  ('Q2480049',
#   'Peanut sauce',
#   'peanut sauce',
#   '',
#   '',
#   'salsa satay',
#   'saté',
#   'salsa di arachidi',
#   'ピーナッツソース'),
#  ('Q43361',
#   "Harry Potter and the Philosopher's Stone",
#   'literary work',
#   'هاري بوتر وحجر الفيلسوف',
#   'Harry Potter und der Stein der Weisen',
#   'Harry Potter y la piedra filosofal',
#   "Harry Potter à l'école des sorciers",
#   'Harry Potter e la pietra filosofale',
#   'ハリー・ポッターと賢者の石'),
#  ('Q2137376',
#   'The Savage Innocents',
#   'film',
#   '',
#   'Im Land der langen Schatten',
#   'Los dientes del diablo',
#   'Les Dents du diable',
#   'Ombre bianche',
#   'バレン'),
#  ('Q2303131',
#   'Wish Upon a Star',
#   'television film',
#   '',
#   'Wenn Wünsche in Erfüllung gehen',
#   'Pide un deseo',
#   "L'étoile filante",
#   'Aiuto sono mia sorella',
#   ''),
#  ('Q1198912',
#   'St. Jerome in His Study',
#   'copper engraving print',
#   '',
#   'Der heilige Hieronymus im Gehäus',
#   'San Jerónimo en su gabinete (Durero)',
#   'Saint Jérôme dans sa cellule',
#   'San Girolamo nella cella',
#   '書斎の聖ヒエロニムス'),
#  ('Q746368',
#   'Great Norwegian Encyclopedia',
#   'national encyclopedia',
#   'الموسوعة النرويجية العظمى',
#   'Store norske leksikon',
#   'Store norske leksikon',
#   'Store norske leksikon',
#   'Store norske leksikon',
#   'ノルウェー百科事典'),
#  ('Q15897',
#   'Amy Winehouse',
#   'human',
#   'إيمي واينهاوس',
#   'Amy Winehouse',
#   'Amy Winehouse',
#   'Amy Winehouse',
#   'Amy Winehouse',
#   'エイミー・ワインハウス'),
#  ('Q7048121',
#   'Jay Gatsby',
#   'fictional human',
#   'جاي غاتسبي',
#   '',
#   'Jay Gatsby',
#   'Jay Gatsby',
#   'Jay Gatsby',
#   'ジェイ・ギャツビー'),
#  ('Q1622572',
#   'Little Women',
#   'anime television series',
#   'فتيات وأمنيات',
#   '',
#   '',
#   'Les Quatre Filles du docteur March',
#   'Piccole donne',
#   '若草の四姉妹'),
#  ('Q5437849',
#   'Fatima Khatun Mosque',
#   'mosque',
#   'مسجد جنين الكبير',
#   '',
#   '',
#   'mosquée Fatima-Khatoun',
#   '',
#   ''),
#  ('Q1514',
#   'Janis Joplin',
#   'human',
#   'جانيس جوبلين',
#   'Janis Joplin',
#   'Janis Joplin',
#   'Janis Joplin',
#   'Janis Joplin',
#   'ジャニス・ジョプリン'),
#  ('Q40930',
#   'Nefertiti',
#   'human',
#   'نفرتيتي',
#   'Nofretete',
#   'Nefertiti',
#   'Néfertiti',
#   'Nefertiti',
#   'ネフェルティティ'),
#  ('Q1790910',
#   'Death of a Salesman',
#   'film',
#   'موت بائع متجول (فيلم 1985)',
#   'Tod eines Handlungsreisenden',
#   'Muerte de un viajante',
#   "Mort d'un commis voyageur",
#   'Morte di un commesso viaggiatore',
#   ''),
#  ('Q13405542',
#   'Getting to YES',
#   'literary work',
#   'الوصول إلى نعم',
#   'Harvard-Konzept',
#   'Obtenga el SI',
#   '',
#   '',
#   ''),
#  ('Q4385827',
#   'Mock & Sweet',
#   'television series',
#   'شجاع وسكر',
#   'Abenteuer im Maulwurfsland',
#   '',
#   'Choupette et Topi',
#   "L'allegro mondo di Talpilandia",
#   'ドリモグだァ!!'),
#  ('Q154045',
#   'Alexei Nikolaevich, Tsarevich of Russia',
#   'human',
#   'ألكسي رومانوف',
#   'Alexei Nikolajewitsch Romanow',
#   'Alejo Nikoláyevich de Rusia',
#   'Alexis Nikolaïevitch de Russie',
#   'Aleksej Nikolaevič Romanov',
#   'アレクセイ・ニコラエヴィチ'),
#  ('Q697145',
#   'Klosterneuburg Monastery',
#   'abbey',
#   '',
#   'Kollegiatstift, später Augustinerchorherrenstift St. Maria, Klosterneuburg, Österreich',
#   'Abadía de Klosterneuburg',
#   'abbaye de Klosterneuburg',
#   'abbazia di Klosterneuburg',
#   'クロスターノイブルク修道院'),
#  ('Q17269',
#   'Tibet Autonomous Region',
#   'autonomous region',
#   'منطقة التبت ذاتية الحكم',
#   'Autonomes Gebiet Tibet',
#   'Tíbet',
#   'région autonome du Tibet',
#   'regione autonoma del Tibet',
#   'チベット自治区'),
#  ('Q6023057',
#   'Indiana Avenue',
#   'neighborhood',
#   '',
#   '',
#   'ave indiana',
#   '',
#   '',
#   ''),
#  ('Q1067463',
#   'Koutloumousiou monastery',
#   'monastery',
#   '',
#   'Kloster Koutloumousiou',
#   'Monasterio de Koutloumoussiou',
#   'monastère de Koutloumousiou',
#   'Monastero di Koutloumousiou',
#   'クトゥルムシウ修道院'),
#  ('Q58590',
#   'Yao Ming',
#   'human',
#   'ياو مينغ',
#   'Yao Ming',
#   'Yao Ming',
#   'Yao Ming',
#   'Yao Ming',
#   '姚明'),
#  ('Q223316',
#   'The Devil Wears Prada',
#   'film',
#   'الشيطان يرتدي برادا',
#   'Der Teufel trägt Prada',
#   'The Devil Wears Prada',
#   "Le diable s'habille en Prada",
#   'Il diavolo veste Prada',
#   'プラダを着た悪魔'),
#  ('Q150665',
#   'Charles VI, Holy Roman Emperor',
#   'human',
#   'كارل السادس، إمبراطور روماني مقدس',
#   'Karl VI.',
#   'Carlos VI del Sacro Imperio Romano Germánico',
#   'Charles VI du Saint-Empire',
#   'Carlo VI del Sacro Romano Impero',
#   'カール6世'),
#  ('Q5317',
#   'Space Needle',
#   'observation tower',
#   'الإبرة الفضائية',
#   'Space Needle',
#   'Space Needle',
#   'Space Needle',
#   'Space Needle',
#   'スペースニードル'),
#  ('Q324546',
#   'Marco Rubio',
#   'human',
#   'ماركو روبيو',
#   'Marco Rubio',
#   'Marco Rubio',
#   'Marco Rubio',
#   'Marco Rubio',
#   'マルコ・ルビオ'),
#  ('Q603256',
#   'Niujie Mosque',
#   'mosque',
#   'مسجد نيوجيه',
#   'Niujie-Moschee',
#   'Mezquita de Niujie',
#   'mosquée de Niujie',
#   'moschea di Niujie',
#   '牛街清真寺'),
#  ('Q1535601',
#   'Golden Age of Piracy',
#   'golden age',
#   'العصر الذهبي للقراصنة',
#   'Goldenes Zeitalter',
#   'Edad de oro de la piratería',
#   "Âge d'or de la piraterie",
#   '',
#   '海賊の黄金時代'),
#  ('Q10921850',
#   'Doraemon Comes Back',
#   'film',
#   '',
#   '',
#   '',
#   '',
#   'Kaettekita Doraemon',
#   '帰ってきたドラえもん'),
#  ('Q895730',
#   'The Rider on the White Horse',
#   'written work',
#   'فارس الحصان الأبيض',
#   'Der Schimmelreiter',
#   '',
#   "L'Homme au cheval blanc",
#   '',
#   '白馬の騎手'),
#  ('Q3374761',
#   'An Idiot Abroad',
#   'television series',
#   'أحمق حول العالم',
#   'Die wundersamen Reisen des Karl Pilkington',
#   'Un idiota de viaje',
#   '',
#   'Scemo di viaggio',
#   ''),
#  ('Q711',
#   'Mongolia',
#   'sovereign state',
#   'منغوليا',
#   'Mongolei',
#   'Mongolia',
#   'Mongolie',
#   'Mongolia',
#   'モンゴル国'),
#  ('Q5176694',
#   'Count Otto Vermis',
#   'fictional human',
#   '',
#   '',
#   'Viv Visión',
#   '',
#   'Varnae',
#   ''),
#  ('Q6501380',
#   'Chinese people',
#   'human population',
#   'صينيون',
#   'Chinesen',
#   'chinos',
#   'peuple chinois',
#   'Cinesi',
#   '中国人'),
#  ('Q41483',
#   'The Good, the Bad and the Ugly',
#   'film',
#   'الطيب والشرس والقبيح',
#   'Zwei glorreiche Halunken',
#   'Il buono, il brutto, il cattivo',
#   'Le Bon, la Brute et le Truand',
#   'Il buono, il brutto, il cattivo',
#   '続・夕陽のガンマン'),
#  ('Q180214',
#   'Black Swan',
#   'film',
#   'البجعة السوداء',
#   'Black Swan',
#   'Black Swan',
#   'Black Swan',
#   'Il cigno nero',
#   'ブラック・スワン'),
#  ('Q11541298',
#   'Nireke no Hitobito',
#   'literary work',
#   '',
#   'Das Haus Nire',
#   '',
#   '',
#   '',
#   '楡家の人びと'),
#  ('Q7539',
#   'Peyton Manning',
#   'human',
#   'بيتون مانينغ',
#   'Peyton Manning',
#   'Peyton Manning',
#   'Peyton Manning',
#   'Peyton Manning',
#   'ペイトン・マニング'),
#  ('Q3685200',
#   'Abbey of the Santissima Trinità',
#   'abbey',
#   '',
#   'Abtei der Heiligen Dreifaltigkeit',
#   'abadía de la Santísima Trinidad de Venosa',
#   'abbaye de la Trinité de Venosa',
#   'abbazia della Santissima Trinità',
#   'ホーリー・トリニティ教会'),
#  ('Q216288',
#   'Garth Brooks',
#   'human',
#   'غارث بروكس',
#   'Garth Brooks',
#   'Garth Brooks',
#   'Garth Brooks',
#   'Garth Brooks',
#   'ガース・ブルックス'),
#  ('Q1660753',
#   'On Stranger Tides',
#   'literary work',
#   'في بحار غريبة',
#   'In fremderen Gezeiten',
#   'En costas extrañas',
#   '',
#   'Mari stregati',
#   '幻影の航海'),
#  ('Q165318',
#   'Crime and Punishment',
#   'literary work',
#   'الجريمة والعقاب',
#   'Schuld und Sühne',
#   'Crimen y castigo',
#   'Crime et châtiment',
#   'Delitto e castigo',
#   '罪と罰'),
#  ('Q231226',
#   'Symphony No. 4',
#   'musical work/composition',
#   '',
#   '4. Sinfonie',
#   'Sinfonía n.º 4',
#   'Symphonie nº 4 de Nielsen',
#   'Sinfonia n. 4',
#   '交響曲第4番 (ニールセン)'),
#  ('Q6988043',
#   'Neighborhood of Make-Believe',
#   'fictional country',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''),
#  ('Q17490239',
#   'Splatoon',
#   'video game',
#   'سبلاتون',
#   'Splatoon',
#   'Splatoon',
#   'Splatoon',
#   'Splatoon',
#   'スプラトゥーン'),
#  ('Q340700',
#   'axis of evil',
#   'political slogan',
#   'محور الشر',
#   'Achse des Bösen',
#   'Eje del mal',
#   'axe du mal',
#   'Asse del Male',
#   '悪の枢軸'),
#  ('Q84318956',
#   'Two of Us',
#   'film',
#   '',
#   'Wir beide',
#   'Entre nosotras',
#   'Deux',
#   'Due',
#   'ふたつの部屋、ふたりの暮らし'),
#  ('Q1035',
#   'Charles Darwin',
#   'human',
#   'تشارلز داروين',
#   'Charles Darwin',
#   'Charles Darwin',
#   'Charles Darwin',
#   'Charles Darwin',
#   'チャールズ・ダーウィン'),
#  ('Q447105',
#   'Princess Anastasia of Greece and Denmark',
#   'human',
#   '',
#   'Anastasia von Griechenland',
#   'Anastasia de Grecia',
#   'May « Nancy » Stewart Worthington Leeds',
#   '',
#   ''),
#  ('Q231213',
#   'Symphony No. 4',
#   'musical work/composition',
#   '',
#   '4. Sinfonie',
#   'Sinfonía n.º 4',
#   'Symphonie nº 4 de Mendelssohn',
#   'Sinfonia n. 4',
#   '交響曲第4番'),
#  ('Q41948417',
#   'Pokémon: Diamond and Pearl: Sinnoh League Victors',
#   'anime television series',
#   '',
#   'Pokémon/Staffel 13',
#   'Pokémon: DP Los Vencedores de la Liga de Sinnoh',
#   '',
#   '',
#   ''),
#  ('Q1542306',
#   '1996 Grammy Awards',
#   'award ceremony',
#   '',
#   'Grammy Awards 1996',
#   'Anexo:Premios Grammy de 1996',
#   '38e cérémonie des Grammy Awards',
#   'Grammy Awards 1996',
#   '第38回グラミー賞'),
#  ('Q1264618',
#   'White Horse Temple',
#   'Buddhist temple',
#   '',
#   'Tempel des weißen Pferdes',
#   'Templo del Caballo Blanco',
#   'temple du Cheval blanc',
#   'Báimǎ-sì',
#   '白馬寺'),
#  ('Q135515',
#   'The Sound and the Fury',
#   'literary work',
#   'الصخب والعنف',
#   'Schall und Wahn',
#   'El ruido y la furia',
#   'Le Bruit et la Fureur',
#   "L'urlo e il furore",
#   '響きと怒り'),
#  ('Q4655722',
#   "A Captain's Duty",
#   'written work',
#   "A Captain's Duty: Somali Pirates, Navy SEALs, and Dangerous Days at Sea",
#   '',
#   'El deber de un capitán',
#   '',
#   'Il dovere di un capitano',
#   'キャプテンの責務'),
#  ('Q1969490',
#   'Trinity River',
#   'river',
#   'نهر ترينيتي',
#   'Trinity River',
#   'Río Trinity',
#   'Trinity',
#   'Trinity',
#   'トリニティ川 (テキサス州)'),
#  ('Q12132',
#   'calendar',
#   'specialty',
#   'تقويم',
#   'Kalender',
#   'calendario',
#   'calendrier',
#   'calendario',
#   '暦'),
#  ('Q164060',
#   'Brandi Carlile',
#   'human',
#   'براندي كارلايل',
#   'Brandi Carlile',
#   'Brandi Carlile',
#   'Brandi Carlile',
#   'Brandi Carlile',
#   'ブランディ・チャーリー'),
#  ('Q2461698',
#   'World of Ice and Fire',
#   'fictional universe',
#   'عالم أغنية الجليد والنار',
#   'Lied-von-Eis-und-Feuer-Universum',
#   'universo de Canción de hielo y fuego',
#   'univers du Trône de fer',
#   'mondo delle Cronache del ghiaccio e del fuoco',
#   '氷と炎の歌の世界'),
#  ('Q451319',
#   'Lev Pontryagin',
#   'human',
#   'ليف بونترياغين',
#   'Lew Semjonowitsch Pontrjagin',
#   'Lev Pontriaguin',
#   'Lev Pontriaguine',
#   'Lev Semënovič Pontrjagin',
#   'レフ・ポントリャーギン'),
#  ('Q97032950',
#   'Valentina Sorogozhskaya',
#   'human',
#   '',
#   'Walentina Michailowna Sorogoschskaja',
#   '',
#   '',
#   '',
#   ''),
#  ('Q4384',
#   'Anthem of the Byelorussian Soviet Socialist Republic',
#   'national anthem',
#   '',
#   'Hymne der Weißrussischen Sozialistische Sowjetrepublik',
#   'himno de la República Socialista Soviética de Bielorrusia',
#   'Hymne de la République socialiste soviétique de Biélorussie',
#   'Inno della Repubblica socialista sovietica bielorussa',
#   '白ロシア・ソビエト社会主義共和国の国歌'),
#  ('Q1822330',
#   "Tsarina's Golden Chamber",
#   'building',
#   '',
#   '',
#   '',
#   'palais Doré de la Tsarine',
#   "Camera d'oro della zarina",
#   ''),
#  ('Q444283',
#   'Man O Man',
#   'television series',
#   '',
#   'Mann-o-Mann',
#   'Uno para todas',
#   '',
#   'Beato tra le donne',
#   ''),
#  ('Q8660',
#   'Karachi',
#   'metropolis',
#   'كراتشي',
#   'Karatschi',
#   'Karachi',
#   'Karachi',
#   'Karachi',
#   'カラチ'),
#  ('Q670098',
#   'Mayerling Castle',
#   'hunting lodge',
#   '',
#   'Schloss Mayerling',
#   '',
#   'château de Mayerling',
#   'Castello di Mayerling',
#   ''),
#  ('Q2631105',
#   'Cello Sonata',
#   'musical work/composition',
#   '',
#   'Sonate für Violoncello und Klavier in g-Moll',
#   'Sonata para violonchelo',
#   'Sonate pour violoncelle et piano',
#   'Sonata per violoncello e pianoforte',
#   'チェロソナタ'),
#  ...]

# %%
def command(query_string:str)->list[tuple]:
    """Raw SQL Executor
    
    ARGS
        **query_string** -- A string of raw sql to execute on the database 

    RETURNS
        A list of results
    NOTES
        Will literally let you do anything be careful
        It opens and closes the SQL connection so you do not have to 
    """
    con = sqlite3.connect('../database/ent.db')
    cur = con.cursor()

    res = cur.execute(query_string)
    res = res.fetchall()

    con.close()

    return res

# %%
def query_by_name(name:str, projections='*', additional='')->list[tuple]:
    """Query over the table specifically by name
    
    ARGS
        **name**        -- Literal name or pattern to match against for names 
        **projections** -- Columns you would like projected (default all columns are returned)
        **additional**  -- Any additional SQL you want to add on to the end of the function call (default none)

    RETURNS
        A list of query results
    EXAMPLES
        1. Query a particular name: `query_by_name("John Smith")` -> [(wiki_id, name, instance_of, ... translations)]
        2. Query over a pattern: `query_by_name("Jo%")` -> [(names that start with 'Jo')]
        3. Query over a pattern projecting only the name and arabic translation: `query_by_name`("Jo%", "name, ar")
    """
    res = command(f'''
        SELECT {projections} FROM entity_translation WHERE name like "{name}" {additional}
    ''')

    return res

def query_by_id(ids:list, projections='*', additional='')->list[tuple]:
    """Perform a query by passing in a list of wiki_ids
    
    ARGS
        **ids** -- A list of wiki_ids to query for i.e ['Q49', 'Q1234']
        **projections** -- A string of columns to project (default all)
        **additional** -- Additional sql to pass into the request (default none)

    RETURNS
        A list of tuples representing the query results 
    """
    ids = [f'\"{x}\"' for x in ids] #annoying requirement to wrap the ids in quotes
    q_string = f'''SELECT {projections} FROM entity_translation WHERE wiki_id IN ({", ".join(ids)}) {additional}'''
    res = command(q_string)

    return res

# %%
query_by_id(["Q62029"])
query_by_name('Friedrich Wilhelm, Duke of Brunswick-Wolfenb\u00fcttel')
# Out:
# [('Q62029',
#   'Friedrich Wilhelm, Duke of Brunswick-Wolfenbüttel',
#   'human',
#   'فريدرخ فيلهلم دوق براونشفايغ-فولفنبوتل',
#   'Friedrich Wilhelm I, Herzog von Braunschweig',
#   'Federico Guillermo de Brunswick-Wolfenbüttel',
#   'Frédéric-Guillaume de Brunswick-Wolfenbüttel',
#   'Federico Guglielmo di Brunswick',
#   'フリードリヒ・ヴィルヘルム')]
